# %% [markdown]
# #Import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')

#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/fruitdataset.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall  #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/fruitdataset.zip
# Out:
# Archive:  /content/drive/MyDrive/fruitdataset.zip
#    creating: fruit dataset/Apple Braeburn/
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_0.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_1.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_10.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_100.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_101.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_102.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_103.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_104.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_105.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_106.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_107.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_108.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_109.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_11.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_110.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_111.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_112.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_113.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_114.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_115.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_116.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_117.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_118.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_119.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_12.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_120.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_121.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_122.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_123.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_124.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_125.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_126.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_127.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_128.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_129.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_13.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_130.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_131.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_132.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_133.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_134.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_135.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_136.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_137.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_138.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_139.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_14.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_140.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_141.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_142.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_143.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_144.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_145.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_146.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_147.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_148.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_149.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_15.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_150.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_151.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_152.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_153.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_154.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_155.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_156.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_157.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_158.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_159.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_16.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_160.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_161.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_162.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_163.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_164.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_165.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_166.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_167.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_168.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_169.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_17.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_170.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_171.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_172.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_173.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_174.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_175.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_176.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_177.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_178.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_179.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_18.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_180.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_181.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_182.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_183.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_184.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_185.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_186.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_187.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_188.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_189.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_19.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_190.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_191.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_192.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_193.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_194.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_195.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_196.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_197.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_198.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_199.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_2.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_20.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_200.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_201.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_202.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_203.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_204.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_205.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_206.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_207.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_208.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_209.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_21.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_210.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_211.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_212.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_213.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_214.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_215.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_216.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_217.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_218.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_219.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_22.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_220.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_221.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_222.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_223.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_224.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_225.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_226.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_227.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_228.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_229.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_23.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_230.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_231.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_232.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_233.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_234.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_235.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_236.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_237.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_238.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_239.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_24.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_240.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_241.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_242.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_243.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_244.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_245.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_246.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_247.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_248.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_249.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_25.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_250.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_251.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_252.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_253.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_254.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_255.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_256.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_257.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_258.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_259.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_26.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_260.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_261.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_262.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_263.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_264.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_265.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_266.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_267.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_268.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_269.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_27.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_270.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_271.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_272.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_273.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_274.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_275.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_276.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_277.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_278.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_279.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_28.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_280.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_281.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_282.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_283.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_284.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_285.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_286.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_287.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_288.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_289.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_29.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_290.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_291.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_292.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_293.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_294.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_295.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_296.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_297.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_298.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_299.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_3.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_30.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_300.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_301.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_302.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_303.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_304.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_305.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_306.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_307.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_308.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_309.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_31.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_310.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_311.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_312.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_313.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_314.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_315.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_316.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_317.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_318.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_319.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_32.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_320.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_321.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_322.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_323.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_324.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_325.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_326.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_327.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_328.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_329.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_33.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_330.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_331.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_332.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_333.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_334.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_335.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_336.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_337.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_338.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_339.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_34.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_340.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_341.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_342.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_343.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_344.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_345.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_346.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_347.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_348.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_349.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_35.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_350.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_351.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_352.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_353.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_354.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_355.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_356.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_357.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_358.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_359.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_36.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_360.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_361.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_362.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_363.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_364.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_365.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_366.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_367.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_368.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_369.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_37.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_370.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_371.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_372.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_373.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_374.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_375.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_376.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_377.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_378.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_379.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_38.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_380.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_381.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_382.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_383.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_384.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_385.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_386.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_387.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_388.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_389.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_39.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_390.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_391.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_392.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_393.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_394.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_395.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_396.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_397.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_398.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_399.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_4.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_40.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_400.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_401.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_402.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_403.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_404.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_405.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_406.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_407.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_408.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_409.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_41.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_410.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_411.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_412.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_413.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_414.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_415.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_416.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_417.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_418.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_419.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_42.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_420.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_421.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_422.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_423.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_424.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_425.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_426.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_427.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_428.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_429.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_43.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_430.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_431.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_432.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_433.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_434.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_435.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_436.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_437.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_438.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_439.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_44.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_440.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_441.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_442.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_443.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_444.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_445.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_446.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_447.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_448.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_449.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_45.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_450.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_451.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_452.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_453.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_454.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_455.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_456.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_457.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_458.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_459.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_46.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_460.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_461.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_462.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_463.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_464.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_465.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_466.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_467.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_468.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_469.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_47.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_470.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_471.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_472.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_473.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_474.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_475.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_476.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_477.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_478.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_479.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_48.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_480.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_481.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_482.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_483.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_484.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_485.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_486.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_487.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_488.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_489.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_49.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_490.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_491.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_5.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_50.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_51.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_52.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_53.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_54.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_55.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_56.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_57.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_58.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_59.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_6.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_60.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_61.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_62.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_63.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_64.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_65.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_66.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_67.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_68.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_69.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_7.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_70.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_71.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_72.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_73.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_74.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_75.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_76.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_77.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_78.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_79.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_8.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_80.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_81.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_82.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_83.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_84.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_85.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_86.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_87.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_88.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_89.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_9.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_90.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_91.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_92.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_93.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_94.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_95.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_96.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_97.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_98.jpg
#   inflating: fruit dataset/Apple Braeburn/Apple Braeburn_99.jpg
#    creating: fruit dataset/Lemon/
#   inflating: fruit dataset/Lemon/Lemon_0.jpg
#   inflating: fruit dataset/Lemon/Lemon_1.jpg
#   inflating: fruit dataset/Lemon/Lemon_10.jpg
#   inflating: fruit dataset/Lemon/Lemon_100.jpg
#   inflating: fruit dataset/Lemon/Lemon_101.jpg
#   inflating: fruit dataset/Lemon/Lemon_102.jpg
#   inflating: fruit dataset/Lemon/Lemon_103.jpg
#   inflating: fruit dataset/Lemon/Lemon_104.jpg
#   inflating: fruit dataset/Lemon/Lemon_105.jpg
#   inflating: fruit dataset/Lemon/Lemon_106.jpg
#   inflating: fruit dataset/Lemon/Lemon_107.jpg
#   inflating: fruit dataset/Lemon/Lemon_108.jpg
#   inflating: fruit dataset/Lemon/Lemon_109.jpg
#   inflating: fruit dataset/Lemon/Lemon_11.jpg
#   inflating: fruit dataset/Lemon/Lemon_110.jpg
#   inflating: fruit dataset/Lemon/Lemon_111.jpg
#   inflating: fruit dataset/Lemon/Lemon_112.jpg
#   inflating: fruit dataset/Lemon/Lemon_113.jpg
#   inflating: fruit dataset/Lemon/Lemon_114.jpg
#   inflating: fruit dataset/Lemon/Lemon_115.jpg
#   inflating: fruit dataset/Lemon/Lemon_116.jpg
#   inflating: fruit dataset/Lemon/Lemon_117.jpg
#   inflating: fruit dataset/Lemon/Lemon_118.jpg
#   inflating: fruit dataset/Lemon/Lemon_119.jpg
#   inflating: fruit dataset/Lemon/Lemon_12.jpg
#   inflating: fruit dataset/Lemon/Lemon_120.jpg
#   inflating: fruit dataset/Lemon/Lemon_121.jpg
#   inflating: fruit dataset/Lemon/Lemon_122.jpg
#   inflating: fruit dataset/Lemon/Lemon_123.jpg
#   inflating: fruit dataset/Lemon/Lemon_124.jpg
#   inflating: fruit dataset/Lemon/Lemon_125.jpg
#   inflating: fruit dataset/Lemon/Lemon_126.jpg
#   inflating: fruit dataset/Lemon/Lemon_127.jpg
#   inflating: fruit dataset/Lemon/Lemon_128.jpg
#   inflating: fruit dataset/Lemon/Lemon_129.jpg
#   inflating: fruit dataset/Lemon/Lemon_13.jpg
#   inflating: fruit dataset/Lemon/Lemon_130.jpg
#   inflating: fruit dataset/Lemon/Lemon_131.jpg
#   inflating: fruit dataset/Lemon/Lemon_132.jpg
#   inflating: fruit dataset/Lemon/Lemon_133.jpg
#   inflating: fruit dataset/Lemon/Lemon_134.jpg
#   inflating: fruit dataset/Lemon/Lemon_135.jpg
#   inflating: fruit dataset/Lemon/Lemon_136.jpg
#   inflating: fruit dataset/Lemon/Lemon_137.jpg
#   inflating: fruit dataset/Lemon/Lemon_138.jpg
#   inflating: fruit dataset/Lemon/Lemon_139.jpg
#   inflating: fruit dataset/Lemon/Lemon_14.jpg
#   inflating: fruit dataset/Lemon/Lemon_140.jpg
#   inflating: fruit dataset/Lemon/Lemon_141.jpg
#   inflating: fruit dataset/Lemon/Lemon_142.jpg
#   inflating: fruit dataset/Lemon/Lemon_143.jpg
#   inflating: fruit dataset/Lemon/Lemon_144.jpg
#   inflating: fruit dataset/Lemon/Lemon_145.jpg
#   inflating: fruit dataset/Lemon/Lemon_146.jpg
#   inflating: fruit dataset/Lemon/Lemon_147.jpg
#   inflating: fruit dataset/Lemon/Lemon_148.jpg
#   inflating: fruit dataset/Lemon/Lemon_149.jpg
#   inflating: fruit dataset/Lemon/Lemon_15.jpg
#   inflating: fruit dataset/Lemon/Lemon_150.jpg
#   inflating: fruit dataset/Lemon/Lemon_151.jpg
#   inflating: fruit dataset/Lemon/Lemon_152.jpg
#   inflating: fruit dataset/Lemon/Lemon_153.jpg
#   inflating: fruit dataset/Lemon/Lemon_154.jpg
#   inflating: fruit dataset/Lemon/Lemon_155.jpg
#   inflating: fruit dataset/Lemon/Lemon_156.jpg
#   inflating: fruit dataset/Lemon/Lemon_157.jpg
#   inflating: fruit dataset/Lemon/Lemon_158.jpg
#   inflating: fruit dataset/Lemon/Lemon_159.jpg
#   inflating: fruit dataset/Lemon/Lemon_16.jpg
#   inflating: fruit dataset/Lemon/Lemon_160.jpg
#   inflating: fruit dataset/Lemon/Lemon_161.jpg
#   inflating: fruit dataset/Lemon/Lemon_162.jpg
#   inflating: fruit dataset/Lemon/Lemon_163.jpg
#   inflating: fruit dataset/Lemon/Lemon_164.jpg
#   inflating: fruit dataset/Lemon/Lemon_165.jpg
#   inflating: fruit dataset/Lemon/Lemon_166.jpg
#   inflating: fruit dataset/Lemon/Lemon_167.jpg
#   inflating: fruit dataset/Lemon/Lemon_168.jpg
#   inflating: fruit dataset/Lemon/Lemon_169.jpg
#   inflating: fruit dataset/Lemon/Lemon_17.jpg
#   inflating: fruit dataset/Lemon/Lemon_170.jpg
#   inflating: fruit dataset/Lemon/Lemon_171.jpg
#   inflating: fruit dataset/Lemon/Lemon_172.jpg
#   inflating: fruit dataset/Lemon/Lemon_173.jpg
#   inflating: fruit dataset/Lemon/Lemon_174.jpg
#   inflating: fruit dataset/Lemon/Lemon_175.jpg
#   inflating: fruit dataset/Lemon/Lemon_176.jpg
#   inflating: fruit dataset/Lemon/Lemon_177.jpg
#   inflating: fruit dataset/Lemon/Lemon_178.jpg
#   inflating: fruit dataset/Lemon/Lemon_179.jpg
#   inflating: fruit dataset/Lemon/Lemon_18.jpg
#   inflating: fruit dataset/Lemon/Lemon_180.jpg
#   inflating: fruit dataset/Lemon/Lemon_181.jpg
#   inflating: fruit dataset/Lemon/Lemon_182.jpg
#   inflating: fruit dataset/Lemon/Lemon_183.jpg
#   inflating: fruit dataset/Lemon/Lemon_184.jpg
#   inflating: fruit dataset/Lemon/Lemon_185.jpg
#   inflating: fruit dataset/Lemon/Lemon_186.jpg
#   inflating: fruit dataset/Lemon/Lemon_187.jpg
#   inflating: fruit dataset/Lemon/Lemon_188.jpg
#   inflating: fruit dataset/Lemon/Lemon_189.jpg
#   inflating: fruit dataset/Lemon/Lemon_19.jpg
#   inflating: fruit dataset/Lemon/Lemon_190.jpg
#   inflating: fruit dataset/Lemon/Lemon_191.jpg
#   inflating: fruit dataset/Lemon/Lemon_192.jpg
#   inflating: fruit dataset/Lemon/Lemon_193.jpg
#   inflating: fruit dataset/Lemon/Lemon_194.jpg
#   inflating: fruit dataset/Lemon/Lemon_195.jpg
#   inflating: fruit dataset/Lemon/Lemon_196.jpg
#   inflating: fruit dataset/Lemon/Lemon_197.jpg
#   inflating: fruit dataset/Lemon/Lemon_198.jpg
#   inflating: fruit dataset/Lemon/Lemon_199.jpg
#   inflating: fruit dataset/Lemon/Lemon_2.jpg
#   inflating: fruit dataset/Lemon/Lemon_20.jpg
#   inflating: fruit dataset/Lemon/Lemon_200.jpg
#   inflating: fruit dataset/Lemon/Lemon_201.jpg
#   inflating: fruit dataset/Lemon/Lemon_202.jpg
#   inflating: fruit dataset/Lemon/Lemon_203.jpg
#   inflating: fruit dataset/Lemon/Lemon_204.jpg
#   inflating: fruit dataset/Lemon/Lemon_205.jpg
#   inflating: fruit dataset/Lemon/Lemon_206.jpg
#   inflating: fruit dataset/Lemon/Lemon_207.jpg
#   inflating: fruit dataset/Lemon/Lemon_208.jpg
#   inflating: fruit dataset/Lemon/Lemon_209.jpg
#   inflating: fruit dataset/Lemon/Lemon_21.jpg
#   inflating: fruit dataset/Lemon/Lemon_210.jpg
#   inflating: fruit dataset/Lemon/Lemon_211.jpg
#   inflating: fruit dataset/Lemon/Lemon_212.jpg
#   inflating: fruit dataset/Lemon/Lemon_213.jpg
#   inflating: fruit dataset/Lemon/Lemon_214.jpg
#   inflating: fruit dataset/Lemon/Lemon_215.jpg
#   inflating: fruit dataset/Lemon/Lemon_216.jpg
#   inflating: fruit dataset/Lemon/Lemon_217.jpg
#   inflating: fruit dataset/Lemon/Lemon_218.jpg
#   inflating: fruit dataset/Lemon/Lemon_219.jpg
#   inflating: fruit dataset/Lemon/Lemon_22.jpg
#   inflating: fruit dataset/Lemon/Lemon_220.jpg
#   inflating: fruit dataset/Lemon/Lemon_221.jpg
#   inflating: fruit dataset/Lemon/Lemon_222.jpg
#   inflating: fruit dataset/Lemon/Lemon_223.jpg
#   inflating: fruit dataset/Lemon/Lemon_224.jpg
#   inflating: fruit dataset/Lemon/Lemon_225.jpg
#   inflating: fruit dataset/Lemon/Lemon_226.jpg
#   inflating: fruit dataset/Lemon/Lemon_227.jpg
#   inflating: fruit dataset/Lemon/Lemon_228.jpg
#   inflating: fruit dataset/Lemon/Lemon_229.jpg
#   inflating: fruit dataset/Lemon/Lemon_23.jpg
#   inflating: fruit dataset/Lemon/Lemon_230.jpg
#   inflating: fruit dataset/Lemon/Lemon_231.jpg
#   inflating: fruit dataset/Lemon/Lemon_232.jpg
#   inflating: fruit dataset/Lemon/Lemon_233.jpg
#   inflating: fruit dataset/Lemon/Lemon_234.jpg
#   inflating: fruit dataset/Lemon/Lemon_235.jpg
#   inflating: fruit dataset/Lemon/Lemon_236.jpg
#   inflating: fruit dataset/Lemon/Lemon_237.jpg
#   inflating: fruit dataset/Lemon/Lemon_238.jpg
#   inflating: fruit dataset/Lemon/Lemon_239.jpg
#   inflating: fruit dataset/Lemon/Lemon_24.jpg
#   inflating: fruit dataset/Lemon/Lemon_240.jpg
#   inflating: fruit dataset/Lemon/Lemon_241.jpg
#   inflating: fruit dataset/Lemon/Lemon_242.jpg
#   inflating: fruit dataset/Lemon/Lemon_243.jpg
#   inflating: fruit dataset/Lemon/Lemon_244.jpg
#   inflating: fruit dataset/Lemon/Lemon_245.jpg
#   inflating: fruit dataset/Lemon/Lemon_246.jpg
#   inflating: fruit dataset/Lemon/Lemon_247.jpg
#   inflating: fruit dataset/Lemon/Lemon_248.jpg
#   inflating: fruit dataset/Lemon/Lemon_249.jpg
#   inflating: fruit dataset/Lemon/Lemon_25.jpg
#   inflating: fruit dataset/Lemon/Lemon_250.jpg
#   inflating: fruit dataset/Lemon/Lemon_251.jpg
#   inflating: fruit dataset/Lemon/Lemon_252.jpg
#   inflating: fruit dataset/Lemon/Lemon_253.jpg
#   inflating: fruit dataset/Lemon/Lemon_254.jpg
#   inflating: fruit dataset/Lemon/Lemon_255.jpg
#   inflating: fruit dataset/Lemon/Lemon_256.jpg
#   inflating: fruit dataset/Lemon/Lemon_257.jpg
#   inflating: fruit dataset/Lemon/Lemon_258.jpg
#   inflating: fruit dataset/Lemon/Lemon_259.jpg
#   inflating: fruit dataset/Lemon/Lemon_26.jpg
#   inflating: fruit dataset/Lemon/Lemon_260.jpg
#   inflating: fruit dataset/Lemon/Lemon_261.jpg
#   inflating: fruit dataset/Lemon/Lemon_262.jpg
#   inflating: fruit dataset/Lemon/Lemon_263.jpg
#   inflating: fruit dataset/Lemon/Lemon_264.jpg
#   inflating: fruit dataset/Lemon/Lemon_265.jpg
#   inflating: fruit dataset/Lemon/Lemon_266.jpg
#   inflating: fruit dataset/Lemon/Lemon_267.jpg
#   inflating: fruit dataset/Lemon/Lemon_268.jpg
#   inflating: fruit dataset/Lemon/Lemon_269.jpg
#   inflating: fruit dataset/Lemon/Lemon_27.jpg
#   inflating: fruit dataset/Lemon/Lemon_270.jpg
#   inflating: fruit dataset/Lemon/Lemon_271.jpg
#   inflating: fruit dataset/Lemon/Lemon_272.jpg
#   inflating: fruit dataset/Lemon/Lemon_273.jpg
#   inflating: fruit dataset/Lemon/Lemon_274.jpg
#   inflating: fruit dataset/Lemon/Lemon_275.jpg
#   inflating: fruit dataset/Lemon/Lemon_276.jpg
#   inflating: fruit dataset/Lemon/Lemon_277.jpg
#   inflating: fruit dataset/Lemon/Lemon_278.jpg
#   inflating: fruit dataset/Lemon/Lemon_279.jpg
#   inflating: fruit dataset/Lemon/Lemon_28.jpg
#   inflating: fruit dataset/Lemon/Lemon_280.jpg
#   inflating: fruit dataset/Lemon/Lemon_281.jpg
#   inflating: fruit dataset/Lemon/Lemon_282.jpg
#   inflating: fruit dataset/Lemon/Lemon_283.jpg
#   inflating: fruit dataset/Lemon/Lemon_284.jpg
#   inflating: fruit dataset/Lemon/Lemon_285.jpg
#   inflating: fruit dataset/Lemon/Lemon_286.jpg
#   inflating: fruit dataset/Lemon/Lemon_287.jpg
#   inflating: fruit dataset/Lemon/Lemon_288.jpg
#   inflating: fruit dataset/Lemon/Lemon_289.jpg
#   inflating: fruit dataset/Lemon/Lemon_29.jpg
#   inflating: fruit dataset/Lemon/Lemon_290.jpg
#   inflating: fruit dataset/Lemon/Lemon_291.jpg
#   inflating: fruit dataset/Lemon/Lemon_292.jpg
#   inflating: fruit dataset/Lemon/Lemon_293.jpg
#   inflating: fruit dataset/Lemon/Lemon_294.jpg
#   inflating: fruit dataset/Lemon/Lemon_295.jpg
#   inflating: fruit dataset/Lemon/Lemon_296.jpg
#   inflating: fruit dataset/Lemon/Lemon_297.jpg
#   inflating: fruit dataset/Lemon/Lemon_298.jpg
#   inflating: fruit dataset/Lemon/Lemon_299.jpg
#   inflating: fruit dataset/Lemon/Lemon_3.jpg
#   inflating: fruit dataset/Lemon/Lemon_30.jpg
#   inflating: fruit dataset/Lemon/Lemon_300.jpg
#   inflating: fruit dataset/Lemon/Lemon_301.jpg
#   inflating: fruit dataset/Lemon/Lemon_302.jpg
#   inflating: fruit dataset/Lemon/Lemon_303.jpg
#   inflating: fruit dataset/Lemon/Lemon_304.jpg
#   inflating: fruit dataset/Lemon/Lemon_305.jpg
#   inflating: fruit dataset/Lemon/Lemon_306.jpg
#   inflating: fruit dataset/Lemon/Lemon_307.jpg
#   inflating: fruit dataset/Lemon/Lemon_308.jpg
#   inflating: fruit dataset/Lemon/Lemon_309.jpg
#   inflating: fruit dataset/Lemon/Lemon_31.jpg
#   inflating: fruit dataset/Lemon/Lemon_310.jpg
#   inflating: fruit dataset/Lemon/Lemon_311.jpg
#   inflating: fruit dataset/Lemon/Lemon_312.jpg
#   inflating: fruit dataset/Lemon/Lemon_313.jpg
#   inflating: fruit dataset/Lemon/Lemon_314.jpg
#   inflating: fruit dataset/Lemon/Lemon_315.jpg
#   inflating: fruit dataset/Lemon/Lemon_316.jpg
#   inflating: fruit dataset/Lemon/Lemon_317.jpg
#   inflating: fruit dataset/Lemon/Lemon_318.jpg
#   inflating: fruit dataset/Lemon/Lemon_319.jpg
#   inflating: fruit dataset/Lemon/Lemon_32.jpg
#   inflating: fruit dataset/Lemon/Lemon_320.jpg
#   inflating: fruit dataset/Lemon/Lemon_321.jpg
#   inflating: fruit dataset/Lemon/Lemon_322.jpg
#   inflating: fruit dataset/Lemon/Lemon_323.jpg
#   inflating: fruit dataset/Lemon/Lemon_324.jpg
#   inflating: fruit dataset/Lemon/Lemon_325.jpg
#   inflating: fruit dataset/Lemon/Lemon_326.jpg
#   inflating: fruit dataset/Lemon/Lemon_327.jpg
#   inflating: fruit dataset/Lemon/Lemon_328.jpg
#   inflating: fruit dataset/Lemon/Lemon_329.jpg
#   inflating: fruit dataset/Lemon/Lemon_33.jpg
#   inflating: fruit dataset/Lemon/Lemon_330.jpg
#   inflating: fruit dataset/Lemon/Lemon_331.jpg
#   inflating: fruit dataset/Lemon/Lemon_332.jpg
#   inflating: fruit dataset/Lemon/Lemon_333.jpg
#   inflating: fruit dataset/Lemon/Lemon_334.jpg
#   inflating: fruit dataset/Lemon/Lemon_335.jpg
#   inflating: fruit dataset/Lemon/Lemon_336.jpg
#   inflating: fruit dataset/Lemon/Lemon_337.jpg
#   inflating: fruit dataset/Lemon/Lemon_338.jpg
#   inflating: fruit dataset/Lemon/Lemon_339.jpg
#   inflating: fruit dataset/Lemon/Lemon_34.jpg
#   inflating: fruit dataset/Lemon/Lemon_340.jpg
#   inflating: fruit dataset/Lemon/Lemon_341.jpg
#   inflating: fruit dataset/Lemon/Lemon_342.jpg
#   inflating: fruit dataset/Lemon/Lemon_343.jpg
#   inflating: fruit dataset/Lemon/Lemon_344.jpg
#   inflating: fruit dataset/Lemon/Lemon_345.jpg
#   inflating: fruit dataset/Lemon/Lemon_346.jpg
#   inflating: fruit dataset/Lemon/Lemon_347.jpg
#   inflating: fruit dataset/Lemon/Lemon_348.jpg
#   inflating: fruit dataset/Lemon/Lemon_349.jpg
#   inflating: fruit dataset/Lemon/Lemon_35.jpg
#   inflating: fruit dataset/Lemon/Lemon_350.jpg
#   inflating: fruit dataset/Lemon/Lemon_351.jpg
#   inflating: fruit dataset/Lemon/Lemon_352.jpg
#   inflating: fruit dataset/Lemon/Lemon_353.jpg
#   inflating: fruit dataset/Lemon/Lemon_354.jpg
#   inflating: fruit dataset/Lemon/Lemon_355.jpg
#   inflating: fruit dataset/Lemon/Lemon_356.jpg
#   inflating: fruit dataset/Lemon/Lemon_357.jpg
#   inflating: fruit dataset/Lemon/Lemon_358.jpg
#   inflating: fruit dataset/Lemon/Lemon_359.jpg
#   inflating: fruit dataset/Lemon/Lemon_36.jpg
#   inflating: fruit dataset/Lemon/Lemon_360.jpg
#   inflating: fruit dataset/Lemon/Lemon_361.jpg
#   inflating: fruit dataset/Lemon/Lemon_362.jpg
#   inflating: fruit dataset/Lemon/Lemon_363.jpg
#   inflating: fruit dataset/Lemon/Lemon_364.jpg
#   inflating: fruit dataset/Lemon/Lemon_365.jpg
#   inflating: fruit dataset/Lemon/Lemon_366.jpg
#   inflating: fruit dataset/Lemon/Lemon_367.jpg
#   inflating: fruit dataset/Lemon/Lemon_368.jpg
#   inflating: fruit dataset/Lemon/Lemon_369.jpg
#   inflating: fruit dataset/Lemon/Lemon_37.jpg
#   inflating: fruit dataset/Lemon/Lemon_370.jpg
#   inflating: fruit dataset/Lemon/Lemon_371.jpg
#   inflating: fruit dataset/Lemon/Lemon_372.jpg
#   inflating: fruit dataset/Lemon/Lemon_373.jpg
#   inflating: fruit dataset/Lemon/Lemon_374.jpg
# ...
#   inflating: fruit dataset/Pineapple/Pineapple_286.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_287.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_288.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_289.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_29.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_290.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_291.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_292.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_293.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_294.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_295.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_296.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_297.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_298.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_299.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_3.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_30.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_300.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_301.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_302.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_303.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_304.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_305.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_306.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_307.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_308.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_309.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_31.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_310.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_311.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_312.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_313.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_314.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_315.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_316.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_317.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_318.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_319.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_32.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_320.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_321.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_322.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_323.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_324.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_325.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_326.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_327.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_328.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_329.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_33.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_330.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_331.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_332.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_333.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_334.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_335.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_336.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_337.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_338.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_339.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_34.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_340.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_341.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_342.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_343.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_344.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_345.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_346.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_347.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_348.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_349.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_35.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_350.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_351.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_352.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_353.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_354.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_355.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_356.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_357.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_358.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_359.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_36.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_360.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_361.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_362.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_363.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_364.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_365.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_366.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_367.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_368.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_369.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_37.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_370.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_371.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_372.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_373.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_374.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_375.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_376.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_377.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_378.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_379.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_38.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_380.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_381.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_382.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_383.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_384.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_385.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_386.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_387.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_388.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_389.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_39.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_390.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_391.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_392.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_393.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_394.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_395.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_396.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_397.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_398.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_399.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_4.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_40.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_400.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_401.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_402.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_403.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_404.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_405.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_406.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_407.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_408.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_409.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_41.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_410.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_411.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_412.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_413.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_414.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_415.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_416.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_417.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_418.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_419.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_42.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_420.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_421.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_422.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_423.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_424.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_425.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_426.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_427.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_428.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_429.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_43.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_430.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_431.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_432.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_433.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_434.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_435.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_436.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_437.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_438.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_439.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_44.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_440.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_441.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_442.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_443.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_444.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_445.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_446.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_447.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_448.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_449.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_45.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_450.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_451.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_452.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_453.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_454.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_455.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_456.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_457.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_458.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_459.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_46.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_460.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_461.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_462.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_463.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_464.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_465.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_466.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_467.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_468.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_469.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_47.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_470.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_471.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_472.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_473.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_474.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_475.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_476.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_477.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_478.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_479.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_48.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_480.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_481.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_482.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_483.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_484.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_485.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_486.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_487.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_488.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_489.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_49.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_5.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_50.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_51.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_52.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_53.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_54.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_55.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_56.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_57.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_58.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_59.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_6.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_60.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_61.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_62.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_63.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_64.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_65.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_66.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_67.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_68.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_69.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_7.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_70.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_71.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_72.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_73.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_74.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_75.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_76.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_77.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_78.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_79.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_8.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_80.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_81.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_82.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_83.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_84.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_85.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_86.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_87.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_88.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_89.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_9.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_90.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_91.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_92.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_93.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_94.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_95.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_96.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_97.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_98.jpg
#   inflating: fruit dataset/Pineapple/Pineapple_99.jpg

# %%
# !pip install pytorch-fid
# !pip install torchmetrics
# !pip install torch-fidelity
# !pip install torchinfo 
# !pip install matplotlib==3.5 #with newer versions of matplotlib this notebook might not run
# %matplotlib inline
# !pip install captum==0.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-fid
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (8.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (1.10.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.1->pytorch-fid) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.1->pytorch-fid) (16.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.2->pytorch-fid) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.1->pytorch-fid) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.1->pytorch-fid) (1.3.0)
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.22.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.1+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.11.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-fidelity
#   Downloading torch_fidelity-0.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (8.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (1.10.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (0.15.2+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-fidelity) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torch-fidelity) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torch-fidelity) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torch-fidelity) (16.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->torch-fidelity) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torch-fidelity) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->torch-fidelity) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->torch-fidelity) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->torch-fidelity) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->torch-fidelity) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torch-fidelity) (1.3.0)
# Installing collected packages: torch-fidelity
# Successfully installed torch-fidelity-0.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting matplotlib==3.5
#   Downloading matplotlib-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 100.2 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5) (2.8.2)
# Collecting setuptools-scm>=4 (from matplotlib==3.5)
#   Downloading setuptools_scm-7.1.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.5) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=4->matplotlib==3.5) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=4->matplotlib==3.5) (4.5.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=4->matplotlib==3.5) (2.0.1)
# Installing collected packages: setuptools-scm, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.5.0 setuptools-scm-7.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting captum==0.5
#   Downloading captum-0.5.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from captum==0.5) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from captum==0.5) (1.22.4)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.10/dist-packages (from captum==0.5) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum==0.5) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6->captum==0.5) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6->captum==0.5) (16.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum==0.5) (7.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->captum==0.5) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=4->matplotlib->captum==0.5) (67.7.2)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=4->matplotlib->captum==0.5) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6->captum==0.5) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6->captum==0.5) (1.3.0)
# Installing collected packages: captum
# Successfully installed captum-0.5.0

# %%
from matplotlib import cm
from matplotlib import patches
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np 
import pandas as pd 
import os
import torch
import torch.nn as nn
import random
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split 
from torch.utils.data import Subset
from PIL import Image
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
import cv2
import torchvision.transforms as T
import torchvision.transforms.functional as F
import time
from torch.utils.data import random_split
from collections import Counter
import datetime
from torchvision.utils import make_grid
import torch.optim as optim
from matplotlib import gridspec
from numpy import linspace
from numpy.random import randn
from numpy import asarray
from torch.nn import functional as F
from tqdm import tqdm
import IPython.display
import torch.backends.cudnn as cudnn
import torchvision.utils as vutils
import PIL.Image
import io
import shutil
from IPython.display import HTML
from pytorch_fid.fid_score import calculate_fid_given_paths
import uuid
import shutil
import torch_fidelity
from torchmetrics.image.inception import InceptionScore
from torchvision.utils import save_image
from torch.utils.data import ConcatDataset, DataLoader
from torchinfo import summary


#from PIL import Image


#We can use our GPU if it's available
print(torch.cuda.is_available())
dev = torch.device('cuda')
print(dev)
# Out:
# True
# cuda

# %% [markdown]
# # Initialization and visualization of our data

# %% [markdown]
# ## Class initialization

# %%
class fruit(Dataset):
  def __init__(self, image_dir, transforms=None): 
        #super().__init__()
    self.transforms = transforms
    self.files = []

    
    self.image_dir = Path(image_dir)
    folders = sorted(os.listdir(self.image_dir))
    for folder in folders:
      class_idx = folders.index(folder)
      folder_dir = self.image_dir/folder
      files = os.listdir(folder_dir)
      self.files += [{"file": folder_dir/x, "class": class_idx} for x in files]

  def __len__(self):
    return len(self.files)

  def __getitem__(self, i):
    item = self.files[i]
    file = str(item['file'])
    class_idx = (item['class'])

    img = Image.open(file).convert("RGB")
    if self.transforms != None:
      img = self.transforms(img)
      return img, class_idx , file
    img = T.ToTensor()(img)
    return img, class_idx , file

# ANOTHER WAY TO VISUALIZE THE IMAGE IS TRHOUGH cv2
    # reading the images and converting them to correct size and color
 #   img = cv2.imread(str(file))
 #   img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)  #cv2 reads in BGR, change to RGB
 #   img /= 255 # diving by 255, needed to visualize correctly the images
 #   img = T.ToTensor()(img)
 #   img = self.transforms(img)

###########################
#def collate_fn(batch):
#    return tuple(zip(*batch))

# %% [markdown]
# ## Explorative data analysis

# %%
image_dir = "/content/fruit dataset"
dataset = fruit(image_dir, transforms=None)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True, drop_last = True, num_workers = 2)


#get a distribution and show the results in a barplot
classes = np.array([class_idx for _, class_idx, _ in dataset])

c = Counter(classes)
replacement = {0:'Apple Braeburn', 1: 'Lemon', 2: 'Pear', 3: 'Pepper Green', 4: 'Pineapple'}
for k, v in list(c.items()):
    c[replacement.get(k, k)] = c.pop(k)
print(c.items()) 
plt.bar(list(c.keys()), list(c.values()))
plt.title('Distribution plots of training images')
plt.show()
# Out:
# dict_items([('Apple Braeburn', 492), ('Lemon', 492), ('Pear', 696), ('Pepper Green', 444), ('Pineapple', 490)])

# %% [markdown]
# ## Visualization of images

# %%
def showarray(a, b = None, fmt='png', title1 = None, title2 = None):
    a = (a - a.min())
    a = a /a.max()
    a = np.uint8(a*255)

    fa = io.BytesIO()
    PIL.Image.fromarray(a).save(fa, fmt)
    if(b!=None):
      b = (b - b.min())
      b = b / b.max()
      b = np.uint8(b * 255)
      fb = io.BytesIO()
      PIL.Image.fromarray(b).save(fb, fmt)
      fig, ax = plt.subplots(1, 2, figsize=(15, 15))
      ax[0].set_xticks([]); ax[0].set_yticks([])
      ax[1].set_xticks([]); ax[1].set_yticks([])
      ax[0].imshow(a)
      ax[0].title.set_text(title1)
      ax[1].imshow(b)
      ax[1].title.set_text(title2)
      plt.show()
    else:
      fig, ax = plt.subplots(figsize=(8, 8))
      ax.set_xticks([]); ax.set_yticks([])
      ax.imshow(a)
      ax.title.set_text(title1)
      plt.show()
  # IPython.display.display(IPython.display.Image(data=fa.getvalue(), width=width, height=height))
  # IPython.display.display(IPython.display.Image(data=fb.getvalue(), width=width, height=height))

# %%
grid_img_normal = vutils.make_grid(next(iter(dataloader))[0], nrow=8)
showarray(grid_img_normal.permute(1, 2, 0), title1 = "Images of all classes")

# %% [markdown]
# # GAN

# %%
# Set random seed for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # This will generate a random seed
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
# Out:
# Random Seed:  999

# %% [markdown]
# ### Generate images 64x64

# %%
image_size = 64
n_classes = 5
embedding_dim = 100
z_dim = 100  #latent dim
outf = "output"

# %%
transform = T.Compose([
    T.Resize((image_size,image_size)),
    T.ToTensor(),
    T.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])])
image_dir = "/content/fruit dataset"
dataset = fruit(image_dir, transforms=transform)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True, drop_last = True, num_workers = 2)

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.label_conditioned_generator = nn.Sequential(nn.Embedding(n_classes, embedding_dim),
                      nn.Linear(embedding_dim, 16))

        self.latent = nn.Sequential(nn.Linear(z_dim, 4*4*512),
                                   nn.LeakyReLU(0.2, inplace=True))

        self.model = nn.Sequential(nn.ConvTranspose2d(513, 64*8, 4, 2, 1, bias=False),  #in_channels, out_channels, kernel_size, stride, padding
                      nn.BatchNorm2d(64*8, momentum=0.1,  eps=0.8),
                      nn.ReLU(True),
                      nn.ConvTranspose2d(64*8, 64*4, 4, 2, 1, bias=False),
                      nn.BatchNorm2d(64*4, momentum=0.1,  eps=0.8),
                      nn.ReLU(True), 
                      nn.ConvTranspose2d(64*4, 64*2, 4, 2, 1, bias=False),
                      nn.BatchNorm2d(64*2, momentum=0.1,  eps=0.8),
                      nn.ReLU(True), 
                      nn.ConvTranspose2d(64*2, 3, 4, 2, 1, bias=False), #3 because our final image has 3 channels
                      nn.Tanh())

    def forward(self, inputs):
        noise_vector, label = inputs
        label_output = self.label_conditioned_generator(label)
        label_output = label_output.view(-1, 1, 4, 4)
        latent_output = self.latent(noise_vector)
        latent_output = latent_output.view(-1, 512, 4, 4)
        concat = torch.cat((latent_output, label_output), dim=1)
        image = self.model(concat)
        return image



##########################################
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.label_condition_disc = nn.Sequential(nn.Embedding(n_classes, embedding_dim),
                      nn.Linear(embedding_dim, 3*64*64))

        self.model = nn.Sequential(nn.Conv2d(6, 64, 4, 2, 1, bias=False),    #in_channels, out_channels, kernel_size, stride, padding,
                      nn.LeakyReLU(0.2, inplace=True),
                      nn.Conv2d(64, 64*2, 4, 2, 1, bias=False),
                      nn.BatchNorm2d(64*2, momentum=0.1,  eps=0.8),
                      nn.LeakyReLU(0.2, inplace=True),
                      nn.Conv2d(64*2, 64*4, 4, 2, 1, bias=False),
                      nn.BatchNorm2d(64*4, momentum=0.1,  eps=0.8),
                      nn.LeakyReLU(0.2, inplace=True), 
                      nn.Flatten(),
                      nn.Dropout(0.4),
                      nn.Linear(64*8*8*4, 1),
                      nn.Sigmoid())
        

    def forward(self, inputs):
        img, label = inputs
        label_output = self.label_condition_disc(label)
        label_output = label_output.view(-1, 3, 64, 64)
        concat = torch.cat((img, label_output), dim=1)
        output = self.model(concat)
        return output

####################################
# custom weights initialization called on generator and discriminator
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        torch.nn.init.normal_(m.weight, 1.0, 0.02)
        torch.nn.init.zeros_(m.bias)

# Create discriminator and generator
generator = Generator().to(dev)
generator.apply(weights_init)
discriminator = Discriminator().to(dev)
discriminator.apply(weights_init)

# Loss function
criterion = nn.BCELoss()

# Define the optimizers for the generator and discriminator models
G_optimizer = optim.Adam(generator.parameters(), lr=0.0001, betas=(0.5, 0.999))
D_optimizer = optim.Adam(discriminator.parameters(), lr=0.0001, betas=(0.5, 0.999))

def generator_loss(label, fake_output):
    gen_loss = criterion(label, fake_output)
    #print(gen_loss)
    return gen_loss

def discriminator_loss(label, output):
    disc_loss = criterion(label, output)
    #print(total_loss)
    return disc_loss

# %% [markdown]
# ## Train

# %%
num_epochs = 2000
D_loss_plot, G_loss_plot, all_fid = [], [], []

if os.path.exists("Training_images"):
  shutil.rmtree('Training_images')

transform_fid = T.Compose([
    T.Resize((image_size,image_size))])

image_dir = "/content/fruit dataset"
training_fid = fruit(image_dir, transforms=transform_fid) 

os.makedirs('Training_images')
for idx in tqdm(range(len(training_fid))):
  img, label, _ = training_fid.__getitem__(idx)
  img.save(f"Training_images/{idx}.png")
# Out:
# 100%|██████████| 2614/2614 [00:03<00:00, 660.94it/s]

# %%
if os.path.exists("image_created"):
  shutil.rmtree('image_created')

if os.path.exists(outf):
  shutil.rmtree(outf)

try:
    os.makedirs(outf)
except OSError:
  pass   

def normalize_images_IS(images): #IS wants input between [0,1]
    # Normalize a batch of images to be between 0 and 1
    max_value = torch.max(images)
    min_value = torch.min(images)
    normalized_images = (images - min_value) / (max_value - min_value)
    return normalized_images

for epoch in range(1, num_epochs+1): 
 
    D_loss_list, G_loss_list = [], []
    
    for index, (real_images, labels, _) in enumerate(dataloader):
        D_optimizer.zero_grad()
        # Real Data
        real_images = real_images.to(dev)
        # Real labels
        labels = labels.to(dev)
        labels = labels.unsqueeze(1).long()
 
        #Real and fake labels (real = 1, fake = 0)
        real_target = torch.ones(real_images.size(0), 1).to(dev)
        fake_target = torch.zeros(real_images.size(0), 1).to(dev)
       
        D_real_loss = discriminator_loss(discriminator((real_images, labels)), real_target)
     
        # Create the noise (starting of the fake images)
        noise_vector = torch.randn(real_images.size(0), z_dim, device=dev)  
        noise_vector = noise_vector.to(dev)
         
        generated_image = generator((noise_vector, labels))
        output = discriminator((generated_image.detach(), labels))
        D_fake_loss = discriminator_loss(output,  fake_target)
 
        # train with fake       
        D_total_loss = (D_real_loss + D_fake_loss) / 2
        D_loss_list.append(D_total_loss)
       
        D_total_loss.backward()
        D_optimizer.step()
 
        # Train generator with real labels
        G_optimizer.zero_grad()
        G_loss = generator_loss(discriminator((generated_image, labels)), real_target)
        G_loss_list.append(G_loss)
 
        G_loss.backward()
        G_optimizer.step()

    if epoch % 20 == 0 or epoch == 1:
      vutils.save_image(real_images[0], '%s/real_samples.png' % outf, normalize=True) 
      #  fake = generator(noise_vector)
      vutils.save_image(generated_image.detach(), '%s/fake_samples_epoch_%03d.png' % (outf, epoch), normalize=True)
    
    D_loss_plot.append(torch.mean(torch.FloatTensor(D_loss_list)))
    G_loss_plot.append(torch.mean(torch.FloatTensor(G_loss_list)))
    
    #FID and IS calculated every 250 epochs
    if epoch % 250 == 0 or epoch == 1:
      try:
        os.makedirs("image_created")
      except OSError:
        pass  
      for _ in tqdm(range(37)):  #like dataloader
        with torch.no_grad():
          noise_vector = torch.randn(64, z_dim, device=dev)   #64 is the batch, ma è come se fossero righe e z_dim le colonne. Aggiornando sempre il noise vector, facciamo si che per ogni batch il noise di partenza sa diverso  quindi gneera immagini diverse per ogni batch
          fake_imgs = generator((noise_vector, labels))  
        for idx in range(fake_imgs.shape[0]):
          fake_img= fake_imgs[idx]
          vutils.save_image(fake_img,f"image_created/{str(uuid.uuid4())}.png",normalize=True)
      fid = calculate_fid_given_paths(['Training_images','image_created'],dims=2048, device = 'cuda',batch_size=64)
      fake_imgs = normalize_images_IS(fake_imgs.cpu())  #to be sure that values are normalized between [0,1]
      inception = InceptionScore(normalize = True)  #to make the inception score accept values between [0,1]
      inception.update(fake_imgs)
      all_fid.append(fid)
      print('Epoch: [%d/%d]: D_loss: %.3f | G_loss: %.3f | IS = mean:%.2f, std:%.2f | FID=%.2f' % (
           (epoch), num_epochs, torch.mean(torch.FloatTensor(D_loss_list)),\
           torch.mean(torch.FloatTensor(G_loss_list)), inception.compute()[0], inception.compute()[1], fid))
      # do checkpointing
      torch.save(generator.state_dict(), '%s/netG_epoch_%d.pth' % (outf, epoch))
      torch.save(discriminator.state_dict(), '%s/netD_epoch_%d.pth' % (outf, epoch))
      shutil.rmtree('image_created')
    else:
      print('Epoch: [%d/%d]: D_loss: %.3f | G_loss: %.3f' % (
           (epoch), num_epochs, torch.mean(torch.FloatTensor(D_loss_list)),\
           torch.mean(torch.FloatTensor(G_loss_list))))
# Out:
# 100%|██████████| 37/37 [00:03<00:00, 10.05it/s]
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:05<00:00, 17.5MB/s]
# 100%|██████████| 41/41 [00:09<00:00,  4.18it/s]
# 100%|██████████| 37/37 [00:08<00:00,  4.13it/s]
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:05<00:00, 18.4MB/s]
# Epoch: [1/2000]: D_loss: 0.510 | G_loss: 0.805 | IS = mean:1.07, std:0.04 | FID=292.28
# Epoch: [2/2000]: D_loss: 0.411 | G_loss: 1.223
# Epoch: [3/2000]: D_loss: 0.396 | G_loss: 1.496
# Epoch: [4/2000]: D_loss: 0.270 | G_loss: 1.980
# Epoch: [5/2000]: D_loss: 0.281 | G_loss: 2.032
# Epoch: [6/2000]: D_loss: 0.367 | G_loss: 1.713
# Epoch: [7/2000]: D_loss: 0.370 | G_loss: 1.755
# Epoch: [8/2000]: D_loss: 0.371 | G_loss: 1.682
# Epoch: [9/2000]: D_loss: 0.384 | G_loss: 1.660
# Epoch: [10/2000]: D_loss: 0.405 | G_loss: 1.750
# Epoch: [11/2000]: D_loss: 0.390 | G_loss: 1.683
# Epoch: [12/2000]: D_loss: 0.390 | G_loss: 1.641
# Epoch: [13/2000]: D_loss: 0.451 | G_loss: 1.512
# Epoch: [14/2000]: D_loss: 0.472 | G_loss: 1.469
# Epoch: [15/2000]: D_loss: 0.470 | G_loss: 1.358
# Epoch: [16/2000]: D_loss: 0.482 | G_loss: 1.308
# Epoch: [17/2000]: D_loss: 0.505 | G_loss: 1.242
# Epoch: [18/2000]: D_loss: 0.481 | G_loss: 1.307
# Epoch: [19/2000]: D_loss: 0.512 | G_loss: 1.294
# Epoch: [20/2000]: D_loss: 0.529 | G_loss: 1.221
# Epoch: [21/2000]: D_loss: 0.508 | G_loss: 1.203
# Epoch: [22/2000]: D_loss: 0.505 | G_loss: 1.243
# Epoch: [23/2000]: D_loss: 0.520 | G_loss: 1.264
# Epoch: [24/2000]: D_loss: 0.528 | G_loss: 1.211
# Epoch: [25/2000]: D_loss: 0.517 | G_loss: 1.229
# Epoch: [26/2000]: D_loss: 0.536 | G_loss: 1.214
# Epoch: [27/2000]: D_loss: 0.531 | G_loss: 1.162
# Epoch: [28/2000]: D_loss: 0.509 | G_loss: 1.190
# Epoch: [29/2000]: D_loss: 0.527 | G_loss: 1.173
# Epoch: [30/2000]: D_loss: 0.545 | G_loss: 1.178
# Epoch: [31/2000]: D_loss: 0.534 | G_loss: 1.180
# Epoch: [32/2000]: D_loss: 0.535 | G_loss: 1.182
# Epoch: [33/2000]: D_loss: 0.555 | G_loss: 1.166
# Epoch: [34/2000]: D_loss: 0.544 | G_loss: 1.175
# Epoch: [35/2000]: D_loss: 0.534 | G_loss: 1.156
# Epoch: [36/2000]: D_loss: 0.527 | G_loss: 1.230
# Epoch: [37/2000]: D_loss: 0.529 | G_loss: 1.198
# Epoch: [38/2000]: D_loss: 0.526 | G_loss: 1.206
# Epoch: [39/2000]: D_loss: 0.519 | G_loss: 1.231
# Epoch: [40/2000]: D_loss: 0.527 | G_loss: 1.251
# Epoch: [41/2000]: D_loss: 0.520 | G_loss: 1.252
# Epoch: [42/2000]: D_loss: 0.522 | G_loss: 1.288
# Epoch: [43/2000]: D_loss: 0.511 | G_loss: 1.224
# Epoch: [44/2000]: D_loss: 0.527 | G_loss: 1.260
# Epoch: [45/2000]: D_loss: 0.535 | G_loss: 1.247
# Epoch: [46/2000]: D_loss: 0.514 | G_loss: 1.129
# Epoch: [47/2000]: D_loss: 0.540 | G_loss: 1.104
# Epoch: [48/2000]: D_loss: 0.529 | G_loss: 1.101
# Epoch: [49/2000]: D_loss: 0.534 | G_loss: 1.075
# Epoch: [50/2000]: D_loss: 0.534 | G_loss: 1.085
# Epoch: [51/2000]: D_loss: 0.536 | G_loss: 1.067
# Epoch: [52/2000]: D_loss: 0.527 | G_loss: 1.088
# Epoch: [53/2000]: D_loss: 0.535 | G_loss: 1.076
# Epoch: [54/2000]: D_loss: 0.539 | G_loss: 1.077
# Epoch: [55/2000]: D_loss: 0.535 | G_loss: 1.102
# Epoch: [56/2000]: D_loss: 0.531 | G_loss: 1.087
# Epoch: [57/2000]: D_loss: 0.547 | G_loss: 1.066
# Epoch: [58/2000]: D_loss: 0.542 | G_loss: 1.079
# Epoch: [59/2000]: D_loss: 0.534 | G_loss: 1.088
# Epoch: [60/2000]: D_loss: 0.533 | G_loss: 1.076
# Epoch: [61/2000]: D_loss: 0.529 | G_loss: 1.111
# Epoch: [62/2000]: D_loss: 0.536 | G_loss: 1.097
# Epoch: [63/2000]: D_loss: 0.521 | G_loss: 1.124
# Epoch: [64/2000]: D_loss: 0.521 | G_loss: 1.117
# Epoch: [65/2000]: D_loss: 0.524 | G_loss: 1.129
# Epoch: [66/2000]: D_loss: 0.509 | G_loss: 1.130
# Epoch: [67/2000]: D_loss: 0.523 | G_loss: 1.145
# Epoch: [68/2000]: D_loss: 0.521 | G_loss: 1.128
# Epoch: [69/2000]: D_loss: 0.511 | G_loss: 1.139
# Epoch: [70/2000]: D_loss: 0.521 | G_loss: 1.148
# Epoch: [71/2000]: D_loss: 0.513 | G_loss: 1.137
# Epoch: [72/2000]: D_loss: 0.516 | G_loss: 1.197
# Epoch: [73/2000]: D_loss: 0.518 | G_loss: 1.168
# Epoch: [74/2000]: D_loss: 0.513 | G_loss: 1.154
# Epoch: [75/2000]: D_loss: 0.511 | G_loss: 1.178
# Epoch: [76/2000]: D_loss: 0.526 | G_loss: 1.149
# Epoch: [77/2000]: D_loss: 0.504 | G_loss: 1.190
# Epoch: [78/2000]: D_loss: 0.517 | G_loss: 1.168
# Epoch: [79/2000]: D_loss: 0.507 | G_loss: 1.184
# Epoch: [80/2000]: D_loss: 0.508 | G_loss: 1.201
# Epoch: [81/2000]: D_loss: 0.502 | G_loss: 1.218
# Epoch: [82/2000]: D_loss: 0.507 | G_loss: 1.188
# Epoch: [83/2000]: D_loss: 0.501 | G_loss: 1.193
# Epoch: [84/2000]: D_loss: 0.504 | G_loss: 1.227
# Epoch: [85/2000]: D_loss: 0.484 | G_loss: 1.238
# Epoch: [86/2000]: D_loss: 0.501 | G_loss: 1.237
# Epoch: [87/2000]: D_loss: 0.499 | G_loss: 1.224
# Epoch: [88/2000]: D_loss: 0.491 | G_loss: 1.243
# Epoch: [89/2000]: D_loss: 0.493 | G_loss: 1.231
# Epoch: [90/2000]: D_loss: 0.500 | G_loss: 1.261
# Epoch: [91/2000]: D_loss: 0.497 | G_loss: 1.254
# Epoch: [92/2000]: D_loss: 0.498 | G_loss: 1.234
# Epoch: [93/2000]: D_loss: 0.489 | G_loss: 1.264
# Epoch: [94/2000]: D_loss: 0.496 | G_loss: 1.245
# Epoch: [95/2000]: D_loss: 0.492 | G_loss: 1.285
# Epoch: [96/2000]: D_loss: 0.498 | G_loss: 1.267
# Epoch: [97/2000]: D_loss: 0.481 | G_loss: 1.273
# Epoch: [98/2000]: D_loss: 0.489 | G_loss: 1.298
# Epoch: [99/2000]: D_loss: 0.484 | G_loss: 1.298
# Epoch: [100/2000]: D_loss: 0.489 | G_loss: 1.262
# Epoch: [101/2000]: D_loss: 0.486 | G_loss: 1.289
# Epoch: [102/2000]: D_loss: 0.477 | G_loss: 1.285
# Epoch: [103/2000]: D_loss: 0.482 | G_loss: 1.317
# Epoch: [104/2000]: D_loss: 0.472 | G_loss: 1.294
# Epoch: [105/2000]: D_loss: 0.474 | G_loss: 1.305
# Epoch: [106/2000]: D_loss: 0.475 | G_loss: 1.325
# Epoch: [107/2000]: D_loss: 0.483 | G_loss: 1.297
# Epoch: [108/2000]: D_loss: 0.481 | G_loss: 1.324
# Epoch: [109/2000]: D_loss: 0.487 | G_loss: 1.322
# Epoch: [110/2000]: D_loss: 0.476 | G_loss: 1.319
# Epoch: [111/2000]: D_loss: 0.471 | G_loss: 1.355
# Epoch: [112/2000]: D_loss: 0.468 | G_loss: 1.339
# Epoch: [113/2000]: D_loss: 0.477 | G_loss: 1.343
# Epoch: [114/2000]: D_loss: 0.479 | G_loss: 1.329
# Epoch: [115/2000]: D_loss: 0.463 | G_loss: 1.355
# Epoch: [116/2000]: D_loss: 0.470 | G_loss: 1.323
# Epoch: [117/2000]: D_loss: 0.485 | G_loss: 1.342
# Epoch: [118/2000]: D_loss: 0.462 | G_loss: 1.332
# Epoch: [119/2000]: D_loss: 0.490 | G_loss: 1.347
# Epoch: [120/2000]: D_loss: 0.471 | G_loss: 1.364
# Epoch: [121/2000]: D_loss: 0.475 | G_loss: 1.366
# Epoch: [122/2000]: D_loss: 0.464 | G_loss: 1.328
# Epoch: [123/2000]: D_loss: 0.466 | G_loss: 1.371
# Epoch: [124/2000]: D_loss: 0.470 | G_loss: 1.365
# Epoch: [125/2000]: D_loss: 0.468 | G_loss: 1.350
# Epoch: [126/2000]: D_loss: 0.475 | G_loss: 1.355
# Epoch: [127/2000]: D_loss: 0.461 | G_loss: 1.386
# Epoch: [128/2000]: D_loss: 0.461 | G_loss: 1.385
# Epoch: [129/2000]: D_loss: 0.456 | G_loss: 1.386
# Epoch: [130/2000]: D_loss: 0.470 | G_loss: 1.370
# Epoch: [131/2000]: D_loss: 0.460 | G_loss: 1.392
# Epoch: [132/2000]: D_loss: 0.474 | G_loss: 1.402
# Epoch: [133/2000]: D_loss: 0.447 | G_loss: 1.404
# Epoch: [134/2000]: D_loss: 0.452 | G_loss: 1.389
# Epoch: [135/2000]: D_loss: 0.454 | G_loss: 1.390
# Epoch: [136/2000]: D_loss: 0.467 | G_loss: 1.430
# Epoch: [137/2000]: D_loss: 0.459 | G_loss: 1.436
# Epoch: [138/2000]: D_loss: 0.455 | G_loss: 1.421
# Epoch: [139/2000]: D_loss: 0.456 | G_loss: 1.405
# Epoch: [140/2000]: D_loss: 0.463 | G_loss: 1.424
# Epoch: [141/2000]: D_loss: 0.455 | G_loss: 1.401
# Epoch: [142/2000]: D_loss: 0.458 | G_loss: 1.393
# Epoch: [143/2000]: D_loss: 0.458 | G_loss: 1.446
# Epoch: [144/2000]: D_loss: 0.447 | G_loss: 1.441
# Epoch: [145/2000]: D_loss: 0.459 | G_loss: 1.410
# Epoch: [146/2000]: D_loss: 0.440 | G_loss: 1.438
# Epoch: [147/2000]: D_loss: 0.447 | G_loss: 1.439
# Epoch: [148/2000]: D_loss: 0.452 | G_loss: 1.446
# Epoch: [149/2000]: D_loss: 0.442 | G_loss: 1.468
# Epoch: [150/2000]: D_loss: 0.457 | G_loss: 1.423
# Epoch: [151/2000]: D_loss: 0.460 | G_loss: 1.461
# Epoch: [152/2000]: D_loss: 0.452 | G_loss: 1.439
# Epoch: [153/2000]: D_loss: 0.448 | G_loss: 1.459
# Epoch: [154/2000]: D_loss: 0.454 | G_loss: 1.461
# Epoch: [155/2000]: D_loss: 0.452 | G_loss: 1.473
# Epoch: [156/2000]: D_loss: 0.435 | G_loss: 1.497
# Epoch: [157/2000]: D_loss: 0.440 | G_loss: 1.484
# Epoch: [158/2000]: D_loss: 0.444 | G_loss: 1.485
# Epoch: [159/2000]: D_loss: 0.449 | G_loss: 1.490
# Epoch: [160/2000]: D_loss: 0.456 | G_loss: 1.490
# Epoch: [161/2000]: D_loss: 0.454 | G_loss: 1.503
# Epoch: [162/2000]: D_loss: 0.436 | G_loss: 1.482
# Epoch: [163/2000]: D_loss: 0.435 | G_loss: 1.514
# Epoch: [164/2000]: D_loss: 0.447 | G_loss: 1.489
# Epoch: [165/2000]: D_loss: 0.437 | G_loss: 1.505
# Epoch: [166/2000]: D_loss: 0.440 | G_loss: 1.483
# Epoch: [167/2000]: D_loss: 0.439 | G_loss: 1.521
# Epoch: [168/2000]: D_loss: 0.445 | G_loss: 1.509
# Epoch: [169/2000]: D_loss: 0.449 | G_loss: 1.527
# Epoch: [170/2000]: D_loss: 0.434 | G_loss: 1.537
# Epoch: [171/2000]: D_loss: 0.433 | G_loss: 1.531
# Epoch: [172/2000]: D_loss: 0.433 | G_loss: 1.535
# Epoch: [173/2000]: D_loss: 0.462 | G_loss: 1.502
# Epoch: [174/2000]: D_loss: 0.425 | G_loss: 1.562
# Epoch: [175/2000]: D_loss: 0.425 | G_loss: 1.548
# Epoch: [176/2000]: D_loss: 0.434 | G_loss: 1.543
# Epoch: [177/2000]: D_loss: 0.428 | G_loss: 1.542
# Epoch: [178/2000]: D_loss: 0.443 | G_loss: 1.525
# Epoch: [179/2000]: D_loss: 0.438 | G_loss: 1.546
# Epoch: [180/2000]: D_loss: 0.427 | G_loss: 1.564
# Epoch: [181/2000]: D_loss: 0.435 | G_loss: 1.546
# Epoch: [182/2000]: D_loss: 0.436 | G_loss: 1.569
# Epoch: [183/2000]: D_loss: 0.442 | G_loss: 1.559
# Epoch: [184/2000]: D_loss: 0.412 | G_loss: 1.580
# Epoch: [185/2000]: D_loss: 0.432 | G_loss: 1.562
# Epoch: [186/2000]: D_loss: 0.434 | G_loss: 1.555
# Epoch: [187/2000]: D_loss: 0.440 | G_loss: 1.576
# Epoch: [188/2000]: D_loss: 0.423 | G_loss: 1.530
# Epoch: [189/2000]: D_loss: 0.426 | G_loss: 1.601
# Epoch: [190/2000]: D_loss: 0.431 | G_loss: 1.562
# Epoch: [191/2000]: D_loss: 0.440 | G_loss: 1.570
# Epoch: [192/2000]: D_loss: 0.434 | G_loss: 1.561
# Epoch: [193/2000]: D_loss: 0.434 | G_loss: 1.605
# Epoch: [194/2000]: D_loss: 0.438 | G_loss: 1.581
# Epoch: [195/2000]: D_loss: 0.430 | G_loss: 1.585
# Epoch: [196/2000]: D_loss: 0.417 | G_loss: 1.588
# Epoch: [197/2000]: D_loss: 0.425 | G_loss: 1.591
# Epoch: [198/2000]: D_loss: 0.440 | G_loss: 1.633
# Epoch: [199/2000]: D_loss: 0.443 | G_loss: 1.589
# Epoch: [200/2000]: D_loss: 0.432 | G_loss: 1.596
# Epoch: [201/2000]: D_loss: 0.429 | G_loss: 1.576
# Epoch: [202/2000]: D_loss: 0.424 | G_loss: 1.588
# Epoch: [203/2000]: D_loss: 0.420 | G_loss: 1.592
# Epoch: [204/2000]: D_loss: 0.420 | G_loss: 1.594
# Epoch: [205/2000]: D_loss: 0.442 | G_loss: 1.611
# Epoch: [206/2000]: D_loss: 0.444 | G_loss: 1.597
# Epoch: [207/2000]: D_loss: 0.425 | G_loss: 1.596
# Epoch: [208/2000]: D_loss: 0.415 | G_loss: 1.663
# Epoch: [209/2000]: D_loss: 0.418 | G_loss: 1.622
# Epoch: [210/2000]: D_loss: 0.427 | G_loss: 1.590
# Epoch: [211/2000]: D_loss: 0.438 | G_loss: 1.612
# Epoch: [212/2000]: D_loss: 0.431 | G_loss: 1.620
# Epoch: [213/2000]: D_loss: 0.414 | G_loss: 1.680
# Epoch: [214/2000]: D_loss: 0.427 | G_loss: 1.654
# Epoch: [215/2000]: D_loss: 0.425 | G_loss: 1.612
# Epoch: [216/2000]: D_loss: 0.434 | G_loss: 1.591
# Epoch: [217/2000]: D_loss: 0.409 | G_loss: 1.665
# Epoch: [218/2000]: D_loss: 0.438 | G_loss: 1.623
# Epoch: [219/2000]: D_loss: 0.413 | G_loss: 1.672
# Epoch: [220/2000]: D_loss: 0.410 | G_loss: 1.641
# Epoch: [221/2000]: D_loss: 0.422 | G_loss: 1.575
# Epoch: [222/2000]: D_loss: 0.426 | G_loss: 1.670
# Epoch: [223/2000]: D_loss: 0.416 | G_loss: 1.662
# Epoch: [224/2000]: D_loss: 0.422 | G_loss: 1.663
# Epoch: [225/2000]: D_loss: 0.417 | G_loss: 1.662
# Epoch: [226/2000]: D_loss: 0.431 | G_loss: 1.644
# Epoch: [227/2000]: D_loss: 0.410 | G_loss: 1.645
# Epoch: [228/2000]: D_loss: 0.409 | G_loss: 1.692
# Epoch: [229/2000]: D_loss: 0.433 | G_loss: 1.700
# Epoch: [230/2000]: D_loss: 0.414 | G_loss: 1.676
# Epoch: [231/2000]: D_loss: 0.419 | G_loss: 1.632
# Epoch: [232/2000]: D_loss: 0.420 | G_loss: 1.671
# Epoch: [233/2000]: D_loss: 0.422 | G_loss: 1.632
# Epoch: [234/2000]: D_loss: 0.413 | G_loss: 1.699
# Epoch: [235/2000]: D_loss: 0.418 | G_loss: 1.644
# Epoch: [236/2000]: D_loss: 0.421 | G_loss: 1.695
# Epoch: [237/2000]: D_loss: 0.413 | G_loss: 1.699
# Epoch: [238/2000]: D_loss: 0.412 | G_loss: 1.694
# Epoch: [239/2000]: D_loss: 0.416 | G_loss: 1.678
# Epoch: [240/2000]: D_loss: 0.414 | G_loss: 1.706
# Epoch: [241/2000]: D_loss: 0.418 | G_loss: 1.718
# Epoch: [242/2000]: D_loss: 0.421 | G_loss: 1.684
# Epoch: [243/2000]: D_loss: 0.416 | G_loss: 1.684
# Epoch: [244/2000]: D_loss: 0.392 | G_loss: 1.747
# Epoch: [245/2000]: D_loss: 0.427 | G_loss: 1.687
# Epoch: [246/2000]: D_loss: 0.402 | G_loss: 1.678
# Epoch: [247/2000]: D_loss: 0.419 | G_loss: 1.682
# Epoch: [248/2000]: D_loss: 0.415 | G_loss: 1.711
# Epoch: [249/2000]: D_loss: 0.409 | G_loss: 1.712
# 100%|██████████| 37/37 [00:03<00:00,  9.67it/s]
# 100%|██████████| 41/41 [00:10<00:00,  3.89it/s]
# 100%|██████████| 37/37 [00:09<00:00,  3.83it/s]
# Epoch: [250/2000]: D_loss: 0.403 | G_loss: 1.694 | IS = mean:2.65, std:0.81 | FID=221.72
# Epoch: [251/2000]: D_loss: 0.418 | G_loss: 1.718
# Epoch: [252/2000]: D_loss: 0.395 | G_loss: 1.734
# Epoch: [253/2000]: D_loss: 0.402 | G_loss: 1.679
# Epoch: [254/2000]: D_loss: 0.421 | G_loss: 1.616
# Epoch: [255/2000]: D_loss: 0.417 | G_loss: 1.707
# Epoch: [256/2000]: D_loss: 0.410 | G_loss: 1.713
# Epoch: [257/2000]: D_loss: 0.400 | G_loss: 1.752
# Epoch: [258/2000]: D_loss: 0.397 | G_loss: 1.783
# Epoch: [259/2000]: D_loss: 0.416 | G_loss: 1.738
# Epoch: [260/2000]: D_loss: 0.399 | G_loss: 1.755
# Epoch: [261/2000]: D_loss: 0.407 | G_loss: 1.699
# Epoch: [262/2000]: D_loss: 0.407 | G_loss: 1.772
# Epoch: [263/2000]: D_loss: 0.418 | G_loss: 1.783
# Epoch: [264/2000]: D_loss: 0.400 | G_loss: 1.759
# Epoch: [265/2000]: D_loss: 0.407 | G_loss: 1.725
# Epoch: [266/2000]: D_loss: 0.407 | G_loss: 1.749
# Epoch: [267/2000]: D_loss: 0.409 | G_loss: 1.738
# Epoch: [268/2000]: D_loss: 0.409 | G_loss: 1.788
# Epoch: [269/2000]: D_loss: 0.401 | G_loss: 1.752
# Epoch: [270/2000]: D_loss: 0.403 | G_loss: 1.750
# Epoch: [271/2000]: D_loss: 0.405 | G_loss: 1.709
# Epoch: [272/2000]: D_loss: 0.399 | G_loss: 1.731
# Epoch: [273/2000]: D_loss: 0.419 | G_loss: 1.843
# Epoch: [274/2000]: D_loss: 0.395 | G_loss: 1.759
# Epoch: [275/2000]: D_loss: 0.402 | G_loss: 1.715
# Epoch: [276/2000]: D_loss: 0.398 | G_loss: 1.761
# Epoch: [277/2000]: D_loss: 0.396 | G_loss: 1.776
# Epoch: [278/2000]: D_loss: 0.401 | G_loss: 1.801
# Epoch: [279/2000]: D_loss: 0.394 | G_loss: 1.710
# Epoch: [280/2000]: D_loss: 0.411 | G_loss: 1.760
# Epoch: [281/2000]: D_loss: 0.405 | G_loss: 1.736
# Epoch: [282/2000]: D_loss: 0.412 | G_loss: 1.771
# Epoch: [283/2000]: D_loss: 0.392 | G_loss: 1.767
# Epoch: [284/2000]: D_loss: 0.412 | G_loss: 1.739
# Epoch: [285/2000]: D_loss: 0.400 | G_loss: 1.746
# Epoch: [286/2000]: D_loss: 0.400 | G_loss: 1.760
# Epoch: [287/2000]: D_loss: 0.398 | G_loss: 1.802
# Epoch: [288/2000]: D_loss: 0.420 | G_loss: 1.784
# Epoch: [289/2000]: D_loss: 0.409 | G_loss: 1.797
# Epoch: [290/2000]: D_loss: 0.387 | G_loss: 1.809
# Epoch: [291/2000]: D_loss: 0.395 | G_loss: 1.803
# Epoch: [292/2000]: D_loss: 0.398 | G_loss: 1.789
# Epoch: [293/2000]: D_loss: 0.411 | G_loss: 1.767
# Epoch: [294/2000]: D_loss: 0.404 | G_loss: 1.777
# Epoch: [295/2000]: D_loss: 0.393 | G_loss: 1.801
# Epoch: [296/2000]: D_loss: 0.401 | G_loss: 1.790
# Epoch: [297/2000]: D_loss: 0.402 | G_loss: 1.811
# Epoch: [298/2000]: D_loss: 0.399 | G_loss: 1.827
# Epoch: [299/2000]: D_loss: 0.398 | G_loss: 1.856
# Epoch: [300/2000]: D_loss: 0.401 | G_loss: 1.822
# Epoch: [301/2000]: D_loss: 0.401 | G_loss: 1.802
# Epoch: [302/2000]: D_loss: 0.385 | G_loss: 1.844
# Epoch: [303/2000]: D_loss: 0.392 | G_loss: 1.846
# Epoch: [304/2000]: D_loss: 0.385 | G_loss: 1.828
# Epoch: [305/2000]: D_loss: 0.394 | G_loss: 1.777
# Epoch: [306/2000]: D_loss: 0.397 | G_loss: 1.821
# Epoch: [307/2000]: D_loss: 0.398 | G_loss: 1.843
# Epoch: [308/2000]: D_loss: 0.405 | G_loss: 1.823
# Epoch: [309/2000]: D_loss: 0.401 | G_loss: 1.851
# Epoch: [310/2000]: D_loss: 0.380 | G_loss: 1.826
# Epoch: [311/2000]: D_loss: 0.399 | G_loss: 1.834
# Epoch: [312/2000]: D_loss: 0.401 | G_loss: 1.845
# Epoch: [313/2000]: D_loss: 0.393 | G_loss: 1.853
# Epoch: [314/2000]: D_loss: 0.395 | G_loss: 1.887
# Epoch: [315/2000]: D_loss: 0.373 | G_loss: 1.857
# Epoch: [316/2000]: D_loss: 0.398 | G_loss: 1.798
# Epoch: [317/2000]: D_loss: 0.393 | G_loss: 1.864
# Epoch: [318/2000]: D_loss: 0.402 | G_loss: 1.834
# Epoch: [319/2000]: D_loss: 0.385 | G_loss: 1.848
# Epoch: [320/2000]: D_loss: 0.377 | G_loss: 1.883
# Epoch: [321/2000]: D_loss: 0.393 | G_loss: 1.787
# Epoch: [322/2000]: D_loss: 0.399 | G_loss: 1.878
# Epoch: [323/2000]: D_loss: 0.397 | G_loss: 1.883
# Epoch: [324/2000]: D_loss: 0.386 | G_loss: 1.879
# Epoch: [325/2000]: D_loss: 0.386 | G_loss: 1.867
# Epoch: [326/2000]: D_loss: 0.390 | G_loss: 1.811
# Epoch: [327/2000]: D_loss: 0.402 | G_loss: 1.841
# Epoch: [328/2000]: D_loss: 0.395 | G_loss: 1.850
# Epoch: [329/2000]: D_loss: 0.381 | G_loss: 1.837
# Epoch: [330/2000]: D_loss: 0.384 | G_loss: 1.869
# Epoch: [331/2000]: D_loss: 0.380 | G_loss: 1.879
# Epoch: [332/2000]: D_loss: 0.371 | G_loss: 1.886
# Epoch: [333/2000]: D_loss: 0.395 | G_loss: 1.878
# Epoch: [334/2000]: D_loss: 0.384 | G_loss: 1.931
# Epoch: [335/2000]: D_loss: 0.393 | G_loss: 1.891
# Epoch: [336/2000]: D_loss: 0.381 | G_loss: 1.901
# Epoch: [337/2000]: D_loss: 0.391 | G_loss: 1.885
# Epoch: [338/2000]: D_loss: 0.389 | G_loss: 1.850
# Epoch: [339/2000]: D_loss: 0.386 | G_loss: 1.876
# Epoch: [340/2000]: D_loss: 0.392 | G_loss: 1.873
# Epoch: [341/2000]: D_loss: 0.390 | G_loss: 1.876
# Epoch: [342/2000]: D_loss: 0.377 | G_loss: 1.872
# Epoch: [343/2000]: D_loss: 0.384 | G_loss: 1.914
# Epoch: [344/2000]: D_loss: 0.390 | G_loss: 1.929
# Epoch: [345/2000]: D_loss: 0.388 | G_loss: 1.877
# Epoch: [346/2000]: D_loss: 0.394 | G_loss: 1.923
# Epoch: [347/2000]: D_loss: 0.379 | G_loss: 1.858
# Epoch: [348/2000]: D_loss: 0.384 | G_loss: 1.909
# Epoch: [349/2000]: D_loss: 0.389 | G_loss: 1.894
# Epoch: [350/2000]: D_loss: 0.380 | G_loss: 1.905
# Epoch: [351/2000]: D_loss: 0.385 | G_loss: 1.942
# Epoch: [352/2000]: D_loss: 0.382 | G_loss: 1.891
# Epoch: [353/2000]: D_loss: 0.386 | G_loss: 1.866
# Epoch: [354/2000]: D_loss: 0.390 | G_loss: 1.880
# Epoch: [355/2000]: D_loss: 0.385 | G_loss: 1.939
# Epoch: [356/2000]: D_loss: 0.394 | G_loss: 1.909
# Epoch: [357/2000]: D_loss: 0.372 | G_loss: 1.891
# Epoch: [358/2000]: D_loss: 0.392 | G_loss: 1.948
# Epoch: [359/2000]: D_loss: 0.394 | G_loss: 1.879
# Epoch: [360/2000]: D_loss: 0.386 | G_loss: 1.919
# Epoch: [361/2000]: D_loss: 0.398 | G_loss: 1.918
# Epoch: [362/2000]: D_loss: 0.386 | G_loss: 1.899
# Epoch: [363/2000]: D_loss: 0.382 | G_loss: 1.922
# Epoch: [364/2000]: D_loss: 0.393 | G_loss: 1.926
# Epoch: [365/2000]: D_loss: 0.396 | G_loss: 1.919
# Epoch: [366/2000]: D_loss: 0.373 | G_loss: 1.949
# Epoch: [367/2000]: D_loss: 0.388 | G_loss: 1.908
# Epoch: [368/2000]: D_loss: 0.395 | G_loss: 1.932
# Epoch: [369/2000]: D_loss: 0.393 | G_loss: 1.920
# Epoch: [370/2000]: D_loss: 0.394 | G_loss: 1.907
# Epoch: [371/2000]: D_loss: 0.373 | G_loss: 1.944
# Epoch: [372/2000]: D_loss: 0.372 | G_loss: 1.921
# Epoch: [373/2000]: D_loss: 0.375 | G_loss: 1.973
# Epoch: [374/2000]: D_loss: 0.393 | G_loss: 1.990
# Epoch: [375/2000]: D_loss: 0.375 | G_loss: 1.926
# Epoch: [376/2000]: D_loss: 0.375 | G_loss: 1.913
# Epoch: [377/2000]: D_loss: 0.380 | G_loss: 1.930
# Epoch: [378/2000]: D_loss: 0.387 | G_loss: 1.989
# Epoch: [379/2000]: D_loss: 0.370 | G_loss: 1.937
# Epoch: [380/2000]: D_loss: 0.383 | G_loss: 1.957
# Epoch: [381/2000]: D_loss: 0.384 | G_loss: 1.949
# Epoch: [382/2000]: D_loss: 0.372 | G_loss: 1.948
# Epoch: [383/2000]: D_loss: 0.368 | G_loss: 1.912
# Epoch: [384/2000]: D_loss: 0.377 | G_loss: 1.971
# Epoch: [385/2000]: D_loss: 0.391 | G_loss: 1.966
# Epoch: [386/2000]: D_loss: 0.393 | G_loss: 1.947
# Epoch: [387/2000]: D_loss: 0.373 | G_loss: 2.002
# Epoch: [388/2000]: D_loss: 0.389 | G_loss: 1.915
# Epoch: [389/2000]: D_loss: 0.377 | G_loss: 1.998
# Epoch: [390/2000]: D_loss: 0.375 | G_loss: 1.996
# Epoch: [391/2000]: D_loss: 0.396 | G_loss: 1.955
# Epoch: [392/2000]: D_loss: 0.380 | G_loss: 1.943
# Epoch: [393/2000]: D_loss: 0.374 | G_loss: 1.928
# Epoch: [394/2000]: D_loss: 0.382 | G_loss: 1.961
# Epoch: [395/2000]: D_loss: 0.375 | G_loss: 1.998
# Epoch: [396/2000]: D_loss: 0.383 | G_loss: 1.994
# Epoch: [397/2000]: D_loss: 0.380 | G_loss: 2.010
# Epoch: [398/2000]: D_loss: 0.378 | G_loss: 1.966
# Epoch: [399/2000]: D_loss: 0.387 | G_loss: 1.966
# Epoch: [400/2000]: D_loss: 0.367 | G_loss: 1.956
# Epoch: [401/2000]: D_loss: 0.392 | G_loss: 1.995
# Epoch: [402/2000]: D_loss: 0.373 | G_loss: 2.000
# Epoch: [403/2000]: D_loss: 0.381 | G_loss: 1.980
# Epoch: [404/2000]: D_loss: 0.384 | G_loss: 2.001
# Epoch: [405/2000]: D_loss: 0.399 | G_loss: 1.991
# Epoch: [406/2000]: D_loss: 0.372 | G_loss: 1.999
# Epoch: [407/2000]: D_loss: 0.370 | G_loss: 1.981
# Epoch: [408/2000]: D_loss: 0.395 | G_loss: 1.973
# Epoch: [409/2000]: D_loss: 0.357 | G_loss: 1.966
# Epoch: [410/2000]: D_loss: 0.378 | G_loss: 1.970
# Epoch: [411/2000]: D_loss: 0.380 | G_loss: 1.948
# Epoch: [412/2000]: D_loss: 0.381 | G_loss: 2.003
# Epoch: [413/2000]: D_loss: 0.368 | G_loss: 1.996
# Epoch: [414/2000]: D_loss: 0.366 | G_loss: 1.966
# Epoch: [415/2000]: D_loss: 0.376 | G_loss: 2.036
# Epoch: [416/2000]: D_loss: 0.382 | G_loss: 2.011
# Epoch: [417/2000]: D_loss: 0.367 | G_loss: 2.024
# Epoch: [418/2000]: D_loss: 0.380 | G_loss: 1.939
# Epoch: [419/2000]: D_loss: 0.394 | G_loss: 2.026
# Epoch: [420/2000]: D_loss: 0.377 | G_loss: 2.011
# Epoch: [421/2000]: D_loss: 0.369 | G_loss: 2.061
# Epoch: [422/2000]: D_loss: 0.377 | G_loss: 2.005
# Epoch: [423/2000]: D_loss: 0.375 | G_loss: 1.973
# Epoch: [424/2000]: D_loss: 0.363 | G_loss: 2.029
# Epoch: [425/2000]: D_loss: 0.375 | G_loss: 2.007
# Epoch: [426/2000]: D_loss: 0.373 | G_loss: 2.015
# Epoch: [427/2000]: D_loss: 0.385 | G_loss: 2.007
# Epoch: [428/2000]: D_loss: 0.372 | G_loss: 2.030
# Epoch: [429/2000]: D_loss: 0.369 | G_loss: 2.054
# Epoch: [430/2000]: D_loss: 0.408 | G_loss: 2.003
# Epoch: [431/2000]: D_loss: 0.374 | G_loss: 2.082
# Epoch: [432/2000]: D_loss: 0.377 | G_loss: 2.077
# Epoch: [433/2000]: D_loss: 0.368 | G_loss: 2.012
# Epoch: [434/2000]: D_loss: 0.374 | G_loss: 2.044
# Epoch: [435/2000]: D_loss: 0.383 | G_loss: 2.024
# Epoch: [436/2000]: D_loss: 0.372 | G_loss: 1.983
# Epoch: [437/2000]: D_loss: 0.384 | G_loss: 2.012
# Epoch: [438/2000]: D_loss: 0.353 | G_loss: 2.010
# Epoch: [439/2000]: D_loss: 0.370 | G_loss: 2.058
# Epoch: [440/2000]: D_loss: 0.372 | G_loss: 2.030
# Epoch: [441/2000]: D_loss: 0.384 | G_loss: 2.016
# Epoch: [442/2000]: D_loss: 0.369 | G_loss: 2.004
# Epoch: [443/2000]: D_loss: 0.386 | G_loss: 2.033
# Epoch: [444/2000]: D_loss: 0.371 | G_loss: 2.032
# Epoch: [445/2000]: D_loss: 0.359 | G_loss: 2.056
# Epoch: [446/2000]: D_loss: 0.365 | G_loss: 2.011
# Epoch: [447/2000]: D_loss: 0.368 | G_loss: 2.058
# Epoch: [448/2000]: D_loss: 0.385 | G_loss: 2.075
# Epoch: [449/2000]: D_loss: 0.364 | G_loss: 2.035
# Epoch: [450/2000]: D_loss: 0.391 | G_loss: 2.022
# Epoch: [451/2000]: D_loss: 0.371 | G_loss: 1.948
# Epoch: [452/2000]: D_loss: 0.373 | G_loss: 2.036
# Epoch: [453/2000]: D_loss: 0.358 | G_loss: 2.083
# Epoch: [454/2000]: D_loss: 0.373 | G_loss: 2.029
# Epoch: [455/2000]: D_loss: 0.364 | G_loss: 2.070
# Epoch: [456/2000]: D_loss: 0.369 | G_loss: 2.013
# Epoch: [457/2000]: D_loss: 0.368 | G_loss: 2.027
# Epoch: [458/2000]: D_loss: 0.389 | G_loss: 1.993
# Epoch: [459/2000]: D_loss: 0.365 | G_loss: 2.086
# Epoch: [460/2000]: D_loss: 0.359 | G_loss: 2.064
# Epoch: [461/2000]: D_loss: 0.369 | G_loss: 2.033
# Epoch: [462/2000]: D_loss: 0.354 | G_loss: 2.129
# Epoch: [463/2000]: D_loss: 0.368 | G_loss: 2.104
# Epoch: [464/2000]: D_loss: 0.364 | G_loss: 2.099
# Epoch: [465/2000]: D_loss: 0.378 | G_loss: 2.088
# Epoch: [466/2000]: D_loss: 0.394 | G_loss: 2.043
# Epoch: [467/2000]: D_loss: 0.380 | G_loss: 2.074
# Epoch: [468/2000]: D_loss: 0.372 | G_loss: 2.069
# Epoch: [469/2000]: D_loss: 0.354 | G_loss: 2.025
# Epoch: [470/2000]: D_loss: 0.371 | G_loss: 2.113
# Epoch: [471/2000]: D_loss: 0.373 | G_loss: 2.081
# Epoch: [472/2000]: D_loss: 0.367 | G_loss: 2.067
# Epoch: [473/2000]: D_loss: 0.365 | G_loss: 2.126
# Epoch: [474/2000]: D_loss: 0.371 | G_loss: 2.079
# Epoch: [475/2000]: D_loss: 0.358 | G_loss: 2.065
# Epoch: [476/2000]: D_loss: 0.368 | G_loss: 2.115
# Epoch: [477/2000]: D_loss: 0.371 | G_loss: 2.054
# Epoch: [478/2000]: D_loss: 0.372 | G_loss: 2.053
# Epoch: [479/2000]: D_loss: 0.400 | G_loss: 2.038
# Epoch: [480/2000]: D_loss: 0.364 | G_loss: 2.074
# Epoch: [481/2000]: D_loss: 0.379 | G_loss: 2.094
# Epoch: [482/2000]: D_loss: 0.368 | G_loss: 2.082
# Epoch: [483/2000]: D_loss: 0.373 | G_loss: 2.085
# Epoch: [484/2000]: D_loss: 0.372 | G_loss: 2.098
# Epoch: [485/2000]: D_loss: 0.356 | G_loss: 2.183
# Epoch: [486/2000]: D_loss: 0.370 | G_loss: 2.055
# Epoch: [487/2000]: D_loss: 0.369 | G_loss: 2.071
# Epoch: [488/2000]: D_loss: 0.365 | G_loss: 2.121
# Epoch: [489/2000]: D_loss: 0.356 | G_loss: 2.120
# Epoch: [490/2000]: D_loss: 0.373 | G_loss: 2.118
# Epoch: [491/2000]: D_loss: 0.364 | G_loss: 2.119
# Epoch: [492/2000]: D_loss: 0.375 | G_loss: 2.076
# Epoch: [493/2000]: D_loss: 0.354 | G_loss: 2.052
# Epoch: [494/2000]: D_loss: 0.371 | G_loss: 2.074
# Epoch: [495/2000]: D_loss: 0.361 | G_loss: 2.103
# Epoch: [496/2000]: D_loss: 0.369 | G_loss: 2.095
# Epoch: [497/2000]: D_loss: 0.363 | G_loss: 2.094
# Epoch: [498/2000]: D_loss: 0.354 | G_loss: 2.120
# Epoch: [499/2000]: D_loss: 0.355 | G_loss: 2.070
# 100%|██████████| 37/37 [00:04<00:00,  9.23it/s]
# 100%|██████████| 41/41 [00:10<00:00,  3.89it/s]
# 100%|██████████| 37/37 [00:09<00:00,  3.86it/s]
# Epoch: [500/2000]: D_loss: 0.370 | G_loss: 2.164 | IS = mean:2.61, std:0.83 | FID=227.03
# Epoch: [501/2000]: D_loss: 0.372 | G_loss: 2.087
# Epoch: [502/2000]: D_loss: 0.347 | G_loss: 2.163
# Epoch: [503/2000]: D_loss: 0.366 | G_loss: 2.192
# Epoch: [504/2000]: D_loss: 0.377 | G_loss: 2.093
# Epoch: [505/2000]: D_loss: 0.363 | G_loss: 2.168
# Epoch: [506/2000]: D_loss: 0.372 | G_loss: 2.140
# Epoch: [507/2000]: D_loss: 0.358 | G_loss: 2.056
# Epoch: [508/2000]: D_loss: 0.377 | G_loss: 2.092
# Epoch: [509/2000]: D_loss: 0.362 | G_loss: 2.178
# Epoch: [510/2000]: D_loss: 0.357 | G_loss: 2.162
# Epoch: [511/2000]: D_loss: 0.360 | G_loss: 2.090
# Epoch: [512/2000]: D_loss: 0.371 | G_loss: 2.076
# Epoch: [513/2000]: D_loss: 0.362 | G_loss: 2.132
# Epoch: [514/2000]: D_loss: 0.360 | G_loss: 2.086
# Epoch: [515/2000]: D_loss: 0.350 | G_loss: 2.152
# Epoch: [516/2000]: D_loss: 0.368 | G_loss: 2.158
# Epoch: [517/2000]: D_loss: 0.363 | G_loss: 2.189
# Epoch: [518/2000]: D_loss: 0.375 | G_loss: 2.134
# Epoch: [519/2000]: D_loss: 0.356 | G_loss: 2.132
# Epoch: [520/2000]: D_loss: 0.366 | G_loss: 2.178
# Epoch: [521/2000]: D_loss: 0.365 | G_loss: 2.105
# Epoch: [522/2000]: D_loss: 0.362 | G_loss: 2.174
# Epoch: [523/2000]: D_loss: 0.365 | G_loss: 2.127
# Epoch: [524/2000]: D_loss: 0.371 | G_loss: 2.159
# Epoch: [525/2000]: D_loss: 0.374 | G_loss: 2.099
# Epoch: [526/2000]: D_loss: 0.359 | G_loss: 2.124
# Epoch: [527/2000]: D_loss: 0.372 | G_loss: 2.165
# Epoch: [528/2000]: D_loss: 0.347 | G_loss: 2.148
# Epoch: [529/2000]: D_loss: 0.362 | G_loss: 2.053
# Epoch: [530/2000]: D_loss: 0.345 | G_loss: 2.177
# Epoch: [531/2000]: D_loss: 0.366 | G_loss: 2.159
# Epoch: [532/2000]: D_loss: 0.364 | G_loss: 2.141
# Epoch: [533/2000]: D_loss: 0.364 | G_loss: 2.156
# Epoch: [534/2000]: D_loss: 0.346 | G_loss: 2.195
# Epoch: [535/2000]: D_loss: 0.373 | G_loss: 2.165
# Epoch: [536/2000]: D_loss: 0.373 | G_loss: 2.122
# Epoch: [537/2000]: D_loss: 0.363 | G_loss: 2.164
# Epoch: [538/2000]: D_loss: 0.359 | G_loss: 2.226
# Epoch: [539/2000]: D_loss: 0.354 | G_loss: 2.143
# Epoch: [540/2000]: D_loss: 0.365 | G_loss: 2.113
# Epoch: [541/2000]: D_loss: 0.376 | G_loss: 2.186
# Epoch: [542/2000]: D_loss: 0.367 | G_loss: 2.152
# Epoch: [543/2000]: D_loss: 0.360 | G_loss: 2.113
# Epoch: [544/2000]: D_loss: 0.366 | G_loss: 2.123
# Epoch: [545/2000]: D_loss: 0.354 | G_loss: 2.158
# Epoch: [546/2000]: D_loss: 0.372 | G_loss: 2.087
# Epoch: [547/2000]: D_loss: 0.372 | G_loss: 2.085
# Epoch: [548/2000]: D_loss: 0.377 | G_loss: 2.166
# Epoch: [549/2000]: D_loss: 0.365 | G_loss: 2.143
# Epoch: [550/2000]: D_loss: 0.367 | G_loss: 2.123
# Epoch: [551/2000]: D_loss: 0.357 | G_loss: 2.213
# Epoch: [552/2000]: D_loss: 0.340 | G_loss: 2.189
# Epoch: [553/2000]: D_loss: 0.361 | G_loss: 2.102
# Epoch: [554/2000]: D_loss: 0.369 | G_loss: 2.191
# Epoch: [555/2000]: D_loss: 0.354 | G_loss: 2.148
# Epoch: [556/2000]: D_loss: 0.358 | G_loss: 2.213
# Epoch: [557/2000]: D_loss: 0.356 | G_loss: 2.202
# Epoch: [558/2000]: D_loss: 0.362 | G_loss: 2.156
# Epoch: [559/2000]: D_loss: 0.363 | G_loss: 2.119
# Epoch: [560/2000]: D_loss: 0.375 | G_loss: 2.157
# Epoch: [561/2000]: D_loss: 0.395 | G_loss: 2.218
# Epoch: [562/2000]: D_loss: 0.347 | G_loss: 2.156
# Epoch: [563/2000]: D_loss: 0.365 | G_loss: 2.150
# Epoch: [564/2000]: D_loss: 0.367 | G_loss: 2.112
# Epoch: [565/2000]: D_loss: 0.356 | G_loss: 2.217
# Epoch: [566/2000]: D_loss: 0.361 | G_loss: 2.222
# Epoch: [567/2000]: D_loss: 0.354 | G_loss: 2.190
# Epoch: [568/2000]: D_loss: 0.358 | G_loss: 2.178
# Epoch: [569/2000]: D_loss: 0.342 | G_loss: 2.206
# Epoch: [570/2000]: D_loss: 0.353 | G_loss: 2.166
# Epoch: [571/2000]: D_loss: 0.349 | G_loss: 2.199
# Epoch: [572/2000]: D_loss: 0.369 | G_loss: 2.174
# Epoch: [573/2000]: D_loss: 0.374 | G_loss: 2.232
# Epoch: [574/2000]: D_loss: 0.351 | G_loss: 2.164
# Epoch: [575/2000]: D_loss: 0.372 | G_loss: 2.187
# Epoch: [576/2000]: D_loss: 0.350 | G_loss: 2.267
# Epoch: [577/2000]: D_loss: 0.350 | G_loss: 2.184
# Epoch: [578/2000]: D_loss: 0.378 | G_loss: 2.193
# Epoch: [579/2000]: D_loss: 0.358 | G_loss: 2.179
# Epoch: [580/2000]: D_loss: 0.357 | G_loss: 2.181
# Epoch: [581/2000]: D_loss: 0.348 | G_loss: 2.195
# Epoch: [582/2000]: D_loss: 0.367 | G_loss: 2.185
# Epoch: [583/2000]: D_loss: 0.349 | G_loss: 2.220
# Epoch: [584/2000]: D_loss: 0.365 | G_loss: 2.149
# Epoch: [585/2000]: D_loss: 0.349 | G_loss: 2.227
# Epoch: [586/2000]: D_loss: 0.352 | G_loss: 2.157
# Epoch: [587/2000]: D_loss: 0.353 | G_loss: 2.194
# Epoch: [588/2000]: D_loss: 0.367 | G_loss: 2.204
# Epoch: [589/2000]: D_loss: 0.345 | G_loss: 2.211
# Epoch: [590/2000]: D_loss: 0.354 | G_loss: 2.151
# Epoch: [591/2000]: D_loss: 0.360 | G_loss: 2.188
# Epoch: [592/2000]: D_loss: 0.373 | G_loss: 2.204
# Epoch: [593/2000]: D_loss: 0.355 | G_loss: 2.229
# Epoch: [594/2000]: D_loss: 0.351 | G_loss: 2.204
# Epoch: [595/2000]: D_loss: 0.373 | G_loss: 2.198
# Epoch: [596/2000]: D_loss: 0.340 | G_loss: 2.227
# Epoch: [597/2000]: D_loss: 0.350 | G_loss: 2.267
# Epoch: [598/2000]: D_loss: 0.346 | G_loss: 2.210
# Epoch: [599/2000]: D_loss: 0.365 | G_loss: 2.189
# Epoch: [600/2000]: D_loss: 0.346 | G_loss: 2.231
# Epoch: [601/2000]: D_loss: 0.347 | G_loss: 2.240
# Epoch: [602/2000]: D_loss: 0.359 | G_loss: 2.206
# Epoch: [603/2000]: D_loss: 0.340 | G_loss: 2.213
# Epoch: [604/2000]: D_loss: 0.355 | G_loss: 2.248
# Epoch: [605/2000]: D_loss: 0.348 | G_loss: 2.241
# Epoch: [606/2000]: D_loss: 0.361 | G_loss: 2.200
# Epoch: [607/2000]: D_loss: 0.343 | G_loss: 2.223
# Epoch: [608/2000]: D_loss: 0.356 | G_loss: 2.191
# Epoch: [609/2000]: D_loss: 0.362 | G_loss: 2.228
# Epoch: [610/2000]: D_loss: 0.361 | G_loss: 2.209
# Epoch: [611/2000]: D_loss: 0.359 | G_loss: 2.290
# Epoch: [612/2000]: D_loss: 0.367 | G_loss: 2.232
# Epoch: [613/2000]: D_loss: 0.356 | G_loss: 2.246
# Epoch: [614/2000]: D_loss: 0.346 | G_loss: 2.258
# Epoch: [615/2000]: D_loss: 0.351 | G_loss: 2.233
# Epoch: [616/2000]: D_loss: 0.348 | G_loss: 2.265
# Epoch: [617/2000]: D_loss: 0.343 | G_loss: 2.259
# Epoch: [618/2000]: D_loss: 0.361 | G_loss: 2.309
# Epoch: [619/2000]: D_loss: 0.364 | G_loss: 2.218
# Epoch: [620/2000]: D_loss: 0.370 | G_loss: 2.215
# Epoch: [621/2000]: D_loss: 0.362 | G_loss: 2.231
# Epoch: [622/2000]: D_loss: 0.352 | G_loss: 2.231
# Epoch: [623/2000]: D_loss: 0.346 | G_loss: 2.227
# Epoch: [624/2000]: D_loss: 0.338 | G_loss: 2.293
# Epoch: [625/2000]: D_loss: 0.342 | G_loss: 2.226
# Epoch: [626/2000]: D_loss: 0.360 | G_loss: 2.231
# Epoch: [627/2000]: D_loss: 0.368 | G_loss: 2.249
# Epoch: [628/2000]: D_loss: 0.354 | G_loss: 2.352
# Epoch: [629/2000]: D_loss: 0.340 | G_loss: 2.270
# Epoch: [630/2000]: D_loss: 0.361 | G_loss: 2.321
# Epoch: [631/2000]: D_loss: 0.349 | G_loss: 2.369
# Epoch: [632/2000]: D_loss: 0.349 | G_loss: 2.278
# Epoch: [633/2000]: D_loss: 0.342 | G_loss: 2.204
# Epoch: [634/2000]: D_loss: 0.363 | G_loss: 2.259
# Epoch: [635/2000]: D_loss: 0.357 | G_loss: 2.270
# Epoch: [636/2000]: D_loss: 0.361 | G_loss: 2.312
# Epoch: [637/2000]: D_loss: 0.363 | G_loss: 2.234
# Epoch: [638/2000]: D_loss: 0.342 | G_loss: 2.216
# Epoch: [639/2000]: D_loss: 0.350 | G_loss: 2.246
# Epoch: [640/2000]: D_loss: 0.339 | G_loss: 2.225
# Epoch: [641/2000]: D_loss: 0.363 | G_loss: 2.202
# Epoch: [642/2000]: D_loss: 0.344 | G_loss: 2.250
# Epoch: [643/2000]: D_loss: 0.350 | G_loss: 2.180
# Epoch: [644/2000]: D_loss: 0.346 | G_loss: 2.240
# Epoch: [645/2000]: D_loss: 0.349 | G_loss: 2.245
# Epoch: [646/2000]: D_loss: 0.354 | G_loss: 2.246
# Epoch: [647/2000]: D_loss: 0.367 | G_loss: 2.274
# Epoch: [648/2000]: D_loss: 0.353 | G_loss: 2.337
# Epoch: [649/2000]: D_loss: 0.340 | G_loss: 2.313
# Epoch: [650/2000]: D_loss: 0.363 | G_loss: 2.318
# Epoch: [651/2000]: D_loss: 0.357 | G_loss: 2.225
# Epoch: [652/2000]: D_loss: 0.355 | G_loss: 2.199
# Epoch: [653/2000]: D_loss: 0.349 | G_loss: 2.274
# Epoch: [654/2000]: D_loss: 0.358 | G_loss: 2.286
# Epoch: [655/2000]: D_loss: 0.358 | G_loss: 2.277
# Epoch: [656/2000]: D_loss: 0.348 | G_loss: 2.272
# Epoch: [657/2000]: D_loss: 0.332 | G_loss: 2.334
# Epoch: [658/2000]: D_loss: 0.348 | G_loss: 2.287
# Epoch: [659/2000]: D_loss: 0.341 | G_loss: 2.332
# Epoch: [660/2000]: D_loss: 0.340 | G_loss: 2.265
# Epoch: [661/2000]: D_loss: 0.353 | G_loss: 2.221
# Epoch: [662/2000]: D_loss: 0.344 | G_loss: 2.293
# Epoch: [663/2000]: D_loss: 0.346 | G_loss: 2.359
# Epoch: [664/2000]: D_loss: 0.357 | G_loss: 2.334
# Epoch: [665/2000]: D_loss: 0.356 | G_loss: 2.302
# Epoch: [666/2000]: D_loss: 0.349 | G_loss: 2.256
# Epoch: [667/2000]: D_loss: 0.358 | G_loss: 2.270
# Epoch: [668/2000]: D_loss: 0.325 | G_loss: 2.314
# Epoch: [669/2000]: D_loss: 0.356 | G_loss: 2.319
# Epoch: [670/2000]: D_loss: 0.357 | G_loss: 2.326
# Epoch: [671/2000]: D_loss: 0.336 | G_loss: 2.299
# Epoch: [672/2000]: D_loss: 0.352 | G_loss: 2.353
# Epoch: [673/2000]: D_loss: 0.350 | G_loss: 2.305
# Epoch: [674/2000]: D_loss: 0.346 | G_loss: 2.296
# Epoch: [675/2000]: D_loss: 0.359 | G_loss: 2.286
# Epoch: [676/2000]: D_loss: 0.352 | G_loss: 2.355
# Epoch: [677/2000]: D_loss: 0.358 | G_loss: 2.355
# Epoch: [678/2000]: D_loss: 0.351 | G_loss: 2.290
# Epoch: [679/2000]: D_loss: 0.366 | G_loss: 2.343
# Epoch: [680/2000]: D_loss: 0.342 | G_loss: 2.234
# Epoch: [681/2000]: D_loss: 0.333 | G_loss: 2.254
# Epoch: [682/2000]: D_loss: 0.356 | G_loss: 2.297
# Epoch: [683/2000]: D_loss: 0.354 | G_loss: 2.308
# Epoch: [684/2000]: D_loss: 0.357 | G_loss: 2.255
# Epoch: [685/2000]: D_loss: 0.350 | G_loss: 2.307
# Epoch: [686/2000]: D_loss: 0.345 | G_loss: 2.309
# Epoch: [687/2000]: D_loss: 0.342 | G_loss: 2.299
# Epoch: [688/2000]: D_loss: 0.363 | G_loss: 2.278
# Epoch: [689/2000]: D_loss: 0.342 | G_loss: 2.220
# Epoch: [690/2000]: D_loss: 0.354 | G_loss: 2.266
# Epoch: [691/2000]: D_loss: 0.334 | G_loss: 2.369
# Epoch: [692/2000]: D_loss: 0.338 | G_loss: 2.316
# Epoch: [693/2000]: D_loss: 0.365 | G_loss: 2.348
# Epoch: [694/2000]: D_loss: 0.367 | G_loss: 2.330
# Epoch: [695/2000]: D_loss: 0.329 | G_loss: 2.362
# Epoch: [696/2000]: D_loss: 0.353 | G_loss: 2.319
# Epoch: [697/2000]: D_loss: 0.360 | G_loss: 2.321
# Epoch: [698/2000]: D_loss: 0.347 | G_loss: 2.346
# Epoch: [699/2000]: D_loss: 0.338 | G_loss: 2.330
# Epoch: [700/2000]: D_loss: 0.355 | G_loss: 2.292
# Epoch: [701/2000]: D_loss: 0.360 | G_loss: 2.290
# Epoch: [702/2000]: D_loss: 0.358 | G_loss: 2.336
# Epoch: [703/2000]: D_loss: 0.357 | G_loss: 2.352
# Epoch: [704/2000]: D_loss: 0.341 | G_loss: 2.292
# Epoch: [705/2000]: D_loss: 0.368 | G_loss: 2.246
# Epoch: [706/2000]: D_loss: 0.341 | G_loss: 2.313
# Epoch: [707/2000]: D_loss: 0.348 | G_loss: 2.280
# Epoch: [708/2000]: D_loss: 0.347 | G_loss: 2.349
# Epoch: [709/2000]: D_loss: 0.358 | G_loss: 2.328
# Epoch: [710/2000]: D_loss: 0.348 | G_loss: 2.337
# Epoch: [711/2000]: D_loss: 0.343 | G_loss: 2.380
# Epoch: [712/2000]: D_loss: 0.354 | G_loss: 2.328
# Epoch: [713/2000]: D_loss: 0.344 | G_loss: 2.304
# Epoch: [714/2000]: D_loss: 0.336 | G_loss: 2.321
# Epoch: [715/2000]: D_loss: 0.330 | G_loss: 2.354
# Epoch: [716/2000]: D_loss: 0.347 | G_loss: 2.360
# Epoch: [717/2000]: D_loss: 0.356 | G_loss: 2.302
# Epoch: [718/2000]: D_loss: 0.345 | G_loss: 2.382
# Epoch: [719/2000]: D_loss: 0.337 | G_loss: 2.336
# Epoch: [720/2000]: D_loss: 0.329 | G_loss: 2.310
# Epoch: [721/2000]: D_loss: 0.338 | G_loss: 2.320
# Epoch: [722/2000]: D_loss: 0.353 | G_loss: 2.331
# Epoch: [723/2000]: D_loss: 0.350 | G_loss: 2.394
# Epoch: [724/2000]: D_loss: 0.357 | G_loss: 2.329
# Epoch: [725/2000]: D_loss: 0.347 | G_loss: 2.328
# Epoch: [726/2000]: D_loss: 0.325 | G_loss: 2.417
# Epoch: [727/2000]: D_loss: 0.341 | G_loss: 2.434
# Epoch: [728/2000]: D_loss: 0.346 | G_loss: 2.323
# Epoch: [729/2000]: D_loss: 0.338 | G_loss: 2.321
# Epoch: [730/2000]: D_loss: 0.347 | G_loss: 2.372
# Epoch: [731/2000]: D_loss: 0.342 | G_loss: 2.363
# Epoch: [732/2000]: D_loss: 0.331 | G_loss: 2.369
# Epoch: [733/2000]: D_loss: 0.350 | G_loss: 2.295
# Epoch: [734/2000]: D_loss: 0.352 | G_loss: 2.373
# Epoch: [735/2000]: D_loss: 0.347 | G_loss: 2.366
# Epoch: [736/2000]: D_loss: 0.349 | G_loss: 2.314
# Epoch: [737/2000]: D_loss: 0.356 | G_loss: 2.322
# Epoch: [738/2000]: D_loss: 0.338 | G_loss: 2.361
# Epoch: [739/2000]: D_loss: 0.348 | G_loss: 2.341
# Epoch: [740/2000]: D_loss: 0.328 | G_loss: 2.323
# Epoch: [741/2000]: D_loss: 0.355 | G_loss: 2.341
# Epoch: [742/2000]: D_loss: 0.333 | G_loss: 2.326
# Epoch: [743/2000]: D_loss: 0.350 | G_loss: 2.321
# Epoch: [744/2000]: D_loss: 0.340 | G_loss: 2.356
# Epoch: [745/2000]: D_loss: 0.354 | G_loss: 2.360
# Epoch: [746/2000]: D_loss: 0.349 | G_loss: 2.433
# Epoch: [747/2000]: D_loss: 0.332 | G_loss: 2.310
# Epoch: [748/2000]: D_loss: 0.357 | G_loss: 2.396
# Epoch: [749/2000]: D_loss: 0.334 | G_loss: 2.403
# 100%|██████████| 37/37 [00:04<00:00,  7.96it/s]
# 100%|██████████| 41/41 [00:10<00:00,  3.91it/s]
# 100%|██████████| 37/37 [00:09<00:00,  3.83it/s]
# Epoch: [750/2000]: D_loss: 0.344 | G_loss: 2.339 | IS = mean:2.43, std:0.80 | FID=231.99
# Epoch: [751/2000]: D_loss: 0.348 | G_loss: 2.352
# Epoch: [752/2000]: D_loss: 0.328 | G_loss: 2.341
# Epoch: [753/2000]: D_loss: 0.361 | G_loss: 2.337
# Epoch: [754/2000]: D_loss: 0.374 | G_loss: 2.385
# Epoch: [755/2000]: D_loss: 0.346 | G_loss: 2.327
# Epoch: [756/2000]: D_loss: 0.353 | G_loss: 2.387
# Epoch: [757/2000]: D_loss: 0.366 | G_loss: 2.321
# Epoch: [758/2000]: D_loss: 0.331 | G_loss: 2.379
# Epoch: [759/2000]: D_loss: 0.359 | G_loss: 2.384
# Epoch: [760/2000]: D_loss: 0.328 | G_loss: 2.355
# Epoch: [761/2000]: D_loss: 0.355 | G_loss: 2.373
# Epoch: [762/2000]: D_loss: 0.351 | G_loss: 2.390
# Epoch: [763/2000]: D_loss: 0.353 | G_loss: 2.392
# Epoch: [764/2000]: D_loss: 0.331 | G_loss: 2.305
# Epoch: [765/2000]: D_loss: 0.348 | G_loss: 2.343
# Epoch: [766/2000]: D_loss: 0.340 | G_loss: 2.359
# Epoch: [767/2000]: D_loss: 0.345 | G_loss: 2.371
# Epoch: [768/2000]: D_loss: 0.338 | G_loss: 2.422
# Epoch: [769/2000]: D_loss: 0.339 | G_loss: 2.391
# Epoch: [770/2000]: D_loss: 0.332 | G_loss: 2.421
# Epoch: [771/2000]: D_loss: 0.344 | G_loss: 2.427
# Epoch: [772/2000]: D_loss: 0.332 | G_loss: 2.365
# Epoch: [773/2000]: D_loss: 0.345 | G_loss: 2.374
# Epoch: [774/2000]: D_loss: 0.357 | G_loss: 2.378
# Epoch: [775/2000]: D_loss: 0.333 | G_loss: 2.365
# Epoch: [776/2000]: D_loss: 0.379 | G_loss: 2.372
# Epoch: [777/2000]: D_loss: 0.321 | G_loss: 2.371
# Epoch: [778/2000]: D_loss: 0.342 | G_loss: 2.447
# Epoch: [779/2000]: D_loss: 0.370 | G_loss: 2.356
# Epoch: [780/2000]: D_loss: 0.344 | G_loss: 2.364
# Epoch: [781/2000]: D_loss: 0.355 | G_loss: 2.385
# Epoch: [782/2000]: D_loss: 0.334 | G_loss: 2.335
# Epoch: [783/2000]: D_loss: 0.344 | G_loss: 2.358
# Epoch: [784/2000]: D_loss: 0.341 | G_loss: 2.366
# Epoch: [785/2000]: D_loss: 0.356 | G_loss: 2.343
# Epoch: [786/2000]: D_loss: 0.350 | G_loss: 2.369
# Epoch: [787/2000]: D_loss: 0.353 | G_loss: 2.399
# Epoch: [788/2000]: D_loss: 0.349 | G_loss: 2.330
# Epoch: [789/2000]: D_loss: 0.341 | G_loss: 2.456
# Epoch: [790/2000]: D_loss: 0.355 | G_loss: 2.346
# Epoch: [791/2000]: D_loss: 0.346 | G_loss: 2.429
# Epoch: [792/2000]: D_loss: 0.343 | G_loss: 2.359
# Epoch: [793/2000]: D_loss: 0.349 | G_loss: 2.420
# Epoch: [794/2000]: D_loss: 0.329 | G_loss: 2.328
# Epoch: [795/2000]: D_loss: 0.360 | G_loss: 2.423
# Epoch: [796/2000]: D_loss: 0.331 | G_loss: 2.396
# Epoch: [797/2000]: D_loss: 0.338 | G_loss: 2.380
# Epoch: [798/2000]: D_loss: 0.337 | G_loss: 2.388
# Epoch: [799/2000]: D_loss: 0.342 | G_loss: 2.432
# Epoch: [800/2000]: D_loss: 0.343 | G_loss: 2.326
# Epoch: [801/2000]: D_loss: 0.349 | G_loss: 2.344
# Epoch: [802/2000]: D_loss: 0.339 | G_loss: 2.378
# Epoch: [803/2000]: D_loss: 0.347 | G_loss: 2.439
# Epoch: [804/2000]: D_loss: 0.325 | G_loss: 2.418
# Epoch: [805/2000]: D_loss: 0.340 | G_loss: 2.441
# Epoch: [806/2000]: D_loss: 0.336 | G_loss: 2.415
# Epoch: [807/2000]: D_loss: 0.345 | G_loss: 2.327
# Epoch: [808/2000]: D_loss: 0.326 | G_loss: 2.343
# Epoch: [809/2000]: D_loss: 0.345 | G_loss: 2.392
# Epoch: [810/2000]: D_loss: 0.353 | G_loss: 2.449
# Epoch: [811/2000]: D_loss: 0.374 | G_loss: 2.316
# Epoch: [812/2000]: D_loss: 0.330 | G_loss: 2.336
# Epoch: [813/2000]: D_loss: 0.351 | G_loss: 2.411
# Epoch: [814/2000]: D_loss: 0.361 | G_loss: 2.343
# Epoch: [815/2000]: D_loss: 0.333 | G_loss: 2.430
# Epoch: [816/2000]: D_loss: 0.341 | G_loss: 2.420
# Epoch: [817/2000]: D_loss: 0.336 | G_loss: 2.414
# Epoch: [818/2000]: D_loss: 0.374 | G_loss: 2.362
# Epoch: [819/2000]: D_loss: 0.348 | G_loss: 2.347
# Epoch: [820/2000]: D_loss: 0.355 | G_loss: 2.341
# Epoch: [821/2000]: D_loss: 0.348 | G_loss: 2.393
# Epoch: [822/2000]: D_loss: 0.335 | G_loss: 2.419
# Epoch: [823/2000]: D_loss: 0.343 | G_loss: 2.392
# Epoch: [824/2000]: D_loss: 0.332 | G_loss: 2.416
# Epoch: [825/2000]: D_loss: 0.339 | G_loss: 2.364
# Epoch: [826/2000]: D_loss: 0.351 | G_loss: 2.343
# Epoch: [827/2000]: D_loss: 0.362 | G_loss: 2.390
# Epoch: [828/2000]: D_loss: 0.333 | G_loss: 2.469
# Epoch: [829/2000]: D_loss: 0.353 | G_loss: 2.350
# Epoch: [830/2000]: D_loss: 0.345 | G_loss: 2.390
# Epoch: [831/2000]: D_loss: 0.353 | G_loss: 2.376
# Epoch: [832/2000]: D_loss: 0.349 | G_loss: 2.392
# Epoch: [833/2000]: D_loss: 0.345 | G_loss: 2.417
# Epoch: [834/2000]: D_loss: 0.371 | G_loss: 2.371
# Epoch: [835/2000]: D_loss: 0.354 | G_loss: 2.424
# Epoch: [836/2000]: D_loss: 0.361 | G_loss: 2.442
# Epoch: [837/2000]: D_loss: 0.340 | G_loss: 2.359
# Epoch: [838/2000]: D_loss: 0.337 | G_loss: 2.379
# Epoch: [839/2000]: D_loss: 0.353 | G_loss: 2.388
# Epoch: [840/2000]: D_loss: 0.357 | G_loss: 2.346
# Epoch: [841/2000]: D_loss: 0.346 | G_loss: 2.414
# Epoch: [842/2000]: D_loss: 0.345 | G_loss: 2.429
# Epoch: [843/2000]: D_loss: 0.369 | G_loss: 2.414
# Epoch: [844/2000]: D_loss: 0.330 | G_loss: 2.485
# Epoch: [845/2000]: D_loss: 0.330 | G_loss: 2.442
# Epoch: [846/2000]: D_loss: 0.352 | G_loss: 2.401
# Epoch: [847/2000]: D_loss: 0.338 | G_loss: 2.453
# Epoch: [848/2000]: D_loss: 0.343 | G_loss: 2.404
# Epoch: [849/2000]: D_loss: 0.351 | G_loss: 2.372
# Epoch: [850/2000]: D_loss: 0.332 | G_loss: 2.392
# Epoch: [851/2000]: D_loss: 0.340 | G_loss: 2.448
# Epoch: [852/2000]: D_loss: 0.339 | G_loss: 2.440
# Epoch: [853/2000]: D_loss: 0.356 | G_loss: 2.442
# Epoch: [854/2000]: D_loss: 0.356 | G_loss: 2.416
# Epoch: [855/2000]: D_loss: 0.335 | G_loss: 2.426
# Epoch: [856/2000]: D_loss: 0.325 | G_loss: 2.433
# Epoch: [857/2000]: D_loss: 0.352 | G_loss: 2.440
# Epoch: [858/2000]: D_loss: 0.346 | G_loss: 2.438
# Epoch: [859/2000]: D_loss: 0.349 | G_loss: 2.467
# Epoch: [860/2000]: D_loss: 0.333 | G_loss: 2.371
# Epoch: [861/2000]: D_loss: 0.337 | G_loss: 2.461
# Epoch: [862/2000]: D_loss: 0.324 | G_loss: 2.442
# Epoch: [863/2000]: D_loss: 0.355 | G_loss: 2.478
# Epoch: [864/2000]: D_loss: 0.344 | G_loss: 2.372
# Epoch: [865/2000]: D_loss: 0.336 | G_loss: 2.482
# Epoch: [866/2000]: D_loss: 0.360 | G_loss: 2.441
# Epoch: [867/2000]: D_loss: 0.342 | G_loss: 2.444
# Epoch: [868/2000]: D_loss: 0.343 | G_loss: 2.430
# Epoch: [869/2000]: D_loss: 0.317 | G_loss: 2.428
# Epoch: [870/2000]: D_loss: 0.361 | G_loss: 2.427
# Epoch: [871/2000]: D_loss: 0.347 | G_loss: 2.389
# Epoch: [872/2000]: D_loss: 0.339 | G_loss: 2.406
# Epoch: [873/2000]: D_loss: 0.337 | G_loss: 2.421
# Epoch: [874/2000]: D_loss: 0.342 | G_loss: 2.427
# Epoch: [875/2000]: D_loss: 0.354 | G_loss: 2.431
# Epoch: [876/2000]: D_loss: 0.326 | G_loss: 2.496
# Epoch: [877/2000]: D_loss: 0.342 | G_loss: 2.495
# Epoch: [878/2000]: D_loss: 0.355 | G_loss: 2.459
# Epoch: [879/2000]: D_loss: 0.346 | G_loss: 2.440
# Epoch: [880/2000]: D_loss: 0.332 | G_loss: 2.462
# Epoch: [881/2000]: D_loss: 0.335 | G_loss: 2.377
# Epoch: [882/2000]: D_loss: 0.337 | G_loss: 2.487
# Epoch: [883/2000]: D_loss: 0.343 | G_loss: 2.400
# Epoch: [884/2000]: D_loss: 0.336 | G_loss: 2.430
# Epoch: [885/2000]: D_loss: 0.350 | G_loss: 2.471
# Epoch: [886/2000]: D_loss: 0.358 | G_loss: 2.470
# Epoch: [887/2000]: D_loss: 0.320 | G_loss: 2.452
# Epoch: [888/2000]: D_loss: 0.368 | G_loss: 2.364
# Epoch: [889/2000]: D_loss: 0.355 | G_loss: 2.403
# Epoch: [890/2000]: D_loss: 0.356 | G_loss: 2.501
# Epoch: [891/2000]: D_loss: 0.376 | G_loss: 2.433
# Epoch: [892/2000]: D_loss: 0.332 | G_loss: 2.358
# Epoch: [893/2000]: D_loss: 0.339 | G_loss: 2.431
# Epoch: [894/2000]: D_loss: 0.342 | G_loss: 2.403
# Epoch: [895/2000]: D_loss: 0.350 | G_loss: 2.412
# Epoch: [896/2000]: D_loss: 0.351 | G_loss: 2.425
# Epoch: [897/2000]: D_loss: 0.340 | G_loss: 2.443
# Epoch: [898/2000]: D_loss: 0.361 | G_loss: 2.474
# Epoch: [899/2000]: D_loss: 0.344 | G_loss: 2.421
# Epoch: [900/2000]: D_loss: 0.338 | G_loss: 2.407
# Epoch: [901/2000]: D_loss: 0.329 | G_loss: 2.502
# Epoch: [902/2000]: D_loss: 0.317 | G_loss: 2.428
# Epoch: [903/2000]: D_loss: 0.346 | G_loss: 2.479
# Epoch: [904/2000]: D_loss: 0.335 | G_loss: 2.488
# Epoch: [905/2000]: D_loss: 0.346 | G_loss: 2.508
# Epoch: [906/2000]: D_loss: 0.352 | G_loss: 2.542
# Epoch: [907/2000]: D_loss: 0.328 | G_loss: 2.454
# Epoch: [908/2000]: D_loss: 0.325 | G_loss: 2.416
# Epoch: [909/2000]: D_loss: 0.350 | G_loss: 2.450
# Epoch: [910/2000]: D_loss: 0.351 | G_loss: 2.423
# Epoch: [911/2000]: D_loss: 0.333 | G_loss: 2.500
# Epoch: [912/2000]: D_loss: 0.346 | G_loss: 2.470
# Epoch: [913/2000]: D_loss: 0.344 | G_loss: 2.434
# Epoch: [914/2000]: D_loss: 0.340 | G_loss: 2.456
# Epoch: [915/2000]: D_loss: 0.316 | G_loss: 2.446
# Epoch: [916/2000]: D_loss: 0.348 | G_loss: 2.472
# Epoch: [917/2000]: D_loss: 0.356 | G_loss: 2.487
# Epoch: [918/2000]: D_loss: 0.344 | G_loss: 2.478
# Epoch: [919/2000]: D_loss: 0.330 | G_loss: 2.464
# Epoch: [920/2000]: D_loss: 0.335 | G_loss: 2.485
# Epoch: [921/2000]: D_loss: 0.361 | G_loss: 2.478
# Epoch: [922/2000]: D_loss: 0.338 | G_loss: 2.481
# Epoch: [923/2000]: D_loss: 0.352 | G_loss: 2.475
# Epoch: [924/2000]: D_loss: 0.339 | G_loss: 2.472
# Epoch: [925/2000]: D_loss: 0.362 | G_loss: 2.497
# Epoch: [926/2000]: D_loss: 0.335 | G_loss: 2.484
# Epoch: [927/2000]: D_loss: 0.331 | G_loss: 2.510
# Epoch: [928/2000]: D_loss: 0.351 | G_loss: 2.387
# Epoch: [929/2000]: D_loss: 0.348 | G_loss: 2.452
# Epoch: [930/2000]: D_loss: 0.330 | G_loss: 2.445
# Epoch: [931/2000]: D_loss: 0.356 | G_loss: 2.419
# Epoch: [932/2000]: D_loss: 0.333 | G_loss: 2.461
# Epoch: [933/2000]: D_loss: 0.365 | G_loss: 2.492
# Epoch: [934/2000]: D_loss: 0.338 | G_loss: 2.380
# Epoch: [935/2000]: D_loss: 0.330 | G_loss: 2.421
# Epoch: [936/2000]: D_loss: 0.335 | G_loss: 2.473
# Epoch: [937/2000]: D_loss: 0.326 | G_loss: 2.429
# Epoch: [938/2000]: D_loss: 0.329 | G_loss: 2.507
# Epoch: [939/2000]: D_loss: 0.336 | G_loss: 2.505
# Epoch: [940/2000]: D_loss: 0.342 | G_loss: 2.473
# Epoch: [941/2000]: D_loss: 0.328 | G_loss: 2.454
# Epoch: [942/2000]: D_loss: 0.346 | G_loss: 2.495
# Epoch: [943/2000]: D_loss: 0.338 | G_loss: 2.510
# Epoch: [944/2000]: D_loss: 0.356 | G_loss: 2.490
# Epoch: [945/2000]: D_loss: 0.332 | G_loss: 2.503
# Epoch: [946/2000]: D_loss: 0.320 | G_loss: 2.503
# Epoch: [947/2000]: D_loss: 0.347 | G_loss: 2.441
# Epoch: [948/2000]: D_loss: 0.340 | G_loss: 2.450
# Epoch: [949/2000]: D_loss: 0.321 | G_loss: 2.529
# Epoch: [950/2000]: D_loss: 0.330 | G_loss: 2.459
# Epoch: [951/2000]: D_loss: 0.369 | G_loss: 2.437
# Epoch: [952/2000]: D_loss: 0.356 | G_loss: 2.491
# Epoch: [953/2000]: D_loss: 0.350 | G_loss: 2.460
# Epoch: [954/2000]: D_loss: 0.355 | G_loss: 2.498
# Epoch: [955/2000]: D_loss: 0.343 | G_loss: 2.495
# Epoch: [956/2000]: D_loss: 0.339 | G_loss: 2.503
# Epoch: [957/2000]: D_loss: 0.330 | G_loss: 2.480
# Epoch: [958/2000]: D_loss: 0.325 | G_loss: 2.470
# Epoch: [959/2000]: D_loss: 0.339 | G_loss: 2.515
# Epoch: [960/2000]: D_loss: 0.339 | G_loss: 2.575
# Epoch: [961/2000]: D_loss: 0.354 | G_loss: 2.435
# Epoch: [962/2000]: D_loss: 0.358 | G_loss: 2.445
# Epoch: [963/2000]: D_loss: 0.344 | G_loss: 2.418
# Epoch: [964/2000]: D_loss: 0.365 | G_loss: 2.526
# Epoch: [965/2000]: D_loss: 0.342 | G_loss: 2.452
# Epoch: [966/2000]: D_loss: 0.337 | G_loss: 2.477
# Epoch: [967/2000]: D_loss: 0.336 | G_loss: 2.501
# Epoch: [968/2000]: D_loss: 0.332 | G_loss: 2.516
# Epoch: [969/2000]: D_loss: 0.355 | G_loss: 2.425
# Epoch: [970/2000]: D_loss: 0.352 | G_loss: 2.454
# Epoch: [971/2000]: D_loss: 0.350 | G_loss: 2.544
# Epoch: [972/2000]: D_loss: 0.336 | G_loss: 2.460
# Epoch: [973/2000]: D_loss: 0.345 | G_loss: 2.490
# Epoch: [974/2000]: D_loss: 0.328 | G_loss: 2.513
# Epoch: [975/2000]: D_loss: 0.332 | G_loss: 2.451
# Epoch: [976/2000]: D_loss: 0.351 | G_loss: 2.498
# Epoch: [977/2000]: D_loss: 0.388 | G_loss: 2.562
# Epoch: [978/2000]: D_loss: 0.363 | G_loss: 2.501
# Epoch: [979/2000]: D_loss: 0.336 | G_loss: 2.476
# Epoch: [980/2000]: D_loss: 0.335 | G_loss: 2.537
# Epoch: [981/2000]: D_loss: 0.325 | G_loss: 2.485
# Epoch: [982/2000]: D_loss: 0.331 | G_loss: 2.441
# Epoch: [983/2000]: D_loss: 0.331 | G_loss: 2.477
# Epoch: [984/2000]: D_loss: 0.352 | G_loss: 2.479
# Epoch: [985/2000]: D_loss: 0.335 | G_loss: 2.552
# Epoch: [986/2000]: D_loss: 0.311 | G_loss: 2.529
# Epoch: [987/2000]: D_loss: 0.318 | G_loss: 2.451
# Epoch: [988/2000]: D_loss: 0.327 | G_loss: 2.479
# Epoch: [989/2000]: D_loss: 0.325 | G_loss: 2.539
# Epoch: [990/2000]: D_loss: 0.337 | G_loss: 2.511
# Epoch: [991/2000]: D_loss: 0.353 | G_loss: 2.485
# Epoch: [992/2000]: D_loss: 0.312 | G_loss: 2.535
# Epoch: [993/2000]: D_loss: 0.325 | G_loss: 2.584
# Epoch: [994/2000]: D_loss: 0.330 | G_loss: 2.575
# Epoch: [995/2000]: D_loss: 0.329 | G_loss: 2.539
# Epoch: [996/2000]: D_loss: 0.355 | G_loss: 2.489
# Epoch: [997/2000]: D_loss: 0.323 | G_loss: 2.526
# Epoch: [998/2000]: D_loss: 0.329 | G_loss: 2.514
# Epoch: [999/2000]: D_loss: 0.354 | G_loss: 2.529
# 100%|██████████| 37/37 [00:03<00:00,  9.92it/s]
# 100%|██████████| 41/41 [00:10<00:00,  3.90it/s]
# 100%|██████████| 37/37 [00:09<00:00,  3.84it/s]
# Epoch: [1000/2000]: D_loss: 0.338 | G_loss: 2.490 | IS = mean:2.42, std:0.60 | FID=233.76
# Epoch: [1001/2000]: D_loss: 0.341 | G_loss: 2.496
# Epoch: [1002/2000]: D_loss: 0.342 | G_loss: 2.450
# Epoch: [1003/2000]: D_loss: 0.317 | G_loss: 2.476
# Epoch: [1004/2000]: D_loss: 0.331 | G_loss: 2.510
# Epoch: [1005/2000]: D_loss: 0.349 | G_loss: 2.580
# Epoch: [1006/2000]: D_loss: 0.327 | G_loss: 2.555
# Epoch: [1007/2000]: D_loss: 0.322 | G_loss: 2.565
# Epoch: [1008/2000]: D_loss: 0.328 | G_loss: 2.499
# Epoch: [1009/2000]: D_loss: 0.328 | G_loss: 2.557
# Epoch: [1010/2000]: D_loss: 0.336 | G_loss: 2.539
# Epoch: [1011/2000]: D_loss: 0.330 | G_loss: 2.569
# Epoch: [1012/2000]: D_loss: 0.336 | G_loss: 2.533
# Epoch: [1013/2000]: D_loss: 0.339 | G_loss: 2.469
# Epoch: [1014/2000]: D_loss: 0.336 | G_loss: 2.492
# Epoch: [1015/2000]: D_loss: 0.321 | G_loss: 2.559
# Epoch: [1016/2000]: D_loss: 0.346 | G_loss: 2.579
# Epoch: [1017/2000]: D_loss: 0.329 | G_loss: 2.507
# Epoch: [1018/2000]: D_loss: 0.328 | G_loss: 2.537
# Epoch: [1019/2000]: D_loss: 0.349 | G_loss: 2.492
# Epoch: [1020/2000]: D_loss: 0.371 | G_loss: 2.471
# Epoch: [1021/2000]: D_loss: 0.341 | G_loss: 2.475
# Epoch: [1022/2000]: D_loss: 0.339 | G_loss: 2.544
# Epoch: [1023/2000]: D_loss: 0.328 | G_loss: 2.535
# Epoch: [1024/2000]: D_loss: 0.323 | G_loss: 2.561
# Epoch: [1025/2000]: D_loss: 0.347 | G_loss: 2.554
# Epoch: [1026/2000]: D_loss: 0.344 | G_loss: 2.507
# Epoch: [1027/2000]: D_loss: 0.367 | G_loss: 2.466
# Epoch: [1028/2000]: D_loss: 0.340 | G_loss: 2.499
# Epoch: [1029/2000]: D_loss: 0.332 | G_loss: 2.492
# Epoch: [1030/2000]: D_loss: 0.333 | G_loss: 2.537
# Epoch: [1031/2000]: D_loss: 0.324 | G_loss: 2.671
# Epoch: [1032/2000]: D_loss: 0.341 | G_loss: 2.557
# Epoch: [1033/2000]: D_loss: 0.331 | G_loss: 2.563
# Epoch: [1034/2000]: D_loss: 0.352 | G_loss: 2.575
# Epoch: [1035/2000]: D_loss: 0.331 | G_loss: 2.507
# Epoch: [1036/2000]: D_loss: 0.339 | G_loss: 2.566
# Epoch: [1037/2000]: D_loss: 0.327 | G_loss: 2.489
# Epoch: [1038/2000]: D_loss: 0.328 | G_loss: 2.586
# Epoch: [1039/2000]: D_loss: 0.330 | G_loss: 2.588
# Epoch: [1040/2000]: D_loss: 0.317 | G_loss: 2.585
# Epoch: [1041/2000]: D_loss: 0.348 | G_loss: 2.532
# Epoch: [1042/2000]: D_loss: 0.342 | G_loss: 2.519
# Epoch: [1043/2000]: D_loss: 0.345 | G_loss: 2.472
# Epoch: [1044/2000]: D_loss: 0.337 | G_loss: 2.536
# Epoch: [1045/2000]: D_loss: 0.311 | G_loss: 2.603
# Epoch: [1046/2000]: D_loss: 0.334 | G_loss: 2.533
# Epoch: [1047/2000]: D_loss: 0.344 | G_loss: 2.491
# Epoch: [1048/2000]: D_loss: 0.357 | G_loss: 2.523
# Epoch: [1049/2000]: D_loss: 0.339 | G_loss: 2.474
# Epoch: [1050/2000]: D_loss: 0.354 | G_loss: 2.506
# Epoch: [1051/2000]: D_loss: 0.341 | G_loss: 2.563
# Epoch: [1052/2000]: D_loss: 0.336 | G_loss: 2.542
# Epoch: [1053/2000]: D_loss: 0.324 | G_loss: 2.558
# Epoch: [1054/2000]: D_loss: 0.336 | G_loss: 2.438
# Epoch: [1055/2000]: D_loss: 0.353 | G_loss: 2.538
# Epoch: [1056/2000]: D_loss: 0.361 | G_loss: 2.524
# Epoch: [1057/2000]: D_loss: 0.318 | G_loss: 2.567
# Epoch: [1058/2000]: D_loss: 0.330 | G_loss: 2.527
# Epoch: [1059/2000]: D_loss: 0.324 | G_loss: 2.540
# Epoch: [1060/2000]: D_loss: 0.322 | G_loss: 2.592
# Epoch: [1061/2000]: D_loss: 0.330 | G_loss: 2.507
# Epoch: [1062/2000]: D_loss: 0.345 | G_loss: 2.522
# Epoch: [1063/2000]: D_loss: 0.318 | G_loss: 2.577
# Epoch: [1064/2000]: D_loss: 0.345 | G_loss: 2.602
# Epoch: [1065/2000]: D_loss: 0.342 | G_loss: 2.511
# Epoch: [1066/2000]: D_loss: 0.332 | G_loss: 2.495
# Epoch: [1067/2000]: D_loss: 0.337 | G_loss: 2.581
# Epoch: [1068/2000]: D_loss: 0.355 | G_loss: 2.541
# Epoch: [1069/2000]: D_loss: 0.332 | G_loss: 2.598
# Epoch: [1070/2000]: D_loss: 0.322 | G_loss: 2.594
# Epoch: [1071/2000]: D_loss: 0.340 | G_loss: 2.576
# Epoch: [1072/2000]: D_loss: 0.340 | G_loss: 2.540
# Epoch: [1073/2000]: D_loss: 0.308 | G_loss: 2.517
# Epoch: [1074/2000]: D_loss: 0.385 | G_loss: 2.589
# Epoch: [1075/2000]: D_loss: 0.340 | G_loss: 2.562
# Epoch: [1076/2000]: D_loss: 0.328 | G_loss: 2.586
# Epoch: [1077/2000]: D_loss: 0.350 | G_loss: 2.558
# Epoch: [1078/2000]: D_loss: 0.349 | G_loss: 2.556
# Epoch: [1079/2000]: D_loss: 0.339 | G_loss: 2.641
# Epoch: [1080/2000]: D_loss: 0.336 | G_loss: 2.526
# Epoch: [1081/2000]: D_loss: 0.327 | G_loss: 2.596
# Epoch: [1082/2000]: D_loss: 0.342 | G_loss: 2.528
# Epoch: [1083/2000]: D_loss: 0.367 | G_loss: 2.587
# Epoch: [1084/2000]: D_loss: 0.319 | G_loss: 2.588
# Epoch: [1085/2000]: D_loss: 0.345 | G_loss: 2.546
# Epoch: [1086/2000]: D_loss: 0.316 | G_loss: 2.524
# Epoch: [1087/2000]: D_loss: 0.333 | G_loss: 2.662
# Epoch: [1088/2000]: D_loss: 0.334 | G_loss: 2.570
# Epoch: [1089/2000]: D_loss: 0.349 | G_loss: 2.566
# Epoch: [1090/2000]: D_loss: 0.333 | G_loss: 2.531
# Epoch: [1091/2000]: D_loss: 0.367 | G_loss: 2.570
# Epoch: [1092/2000]: D_loss: 0.331 | G_loss: 2.544
# Epoch: [1093/2000]: D_loss: 0.320 | G_loss: 2.548
# Epoch: [1094/2000]: D_loss: 0.345 | G_loss: 2.516
# Epoch: [1095/2000]: D_loss: 0.318 | G_loss: 2.619
# Epoch: [1096/2000]: D_loss: 0.345 | G_loss: 2.593
# Epoch: [1097/2000]: D_loss: 0.334 | G_loss: 2.539
# Epoch: [1098/2000]: D_loss: 0.343 | G_loss: 2.515
# Epoch: [1099/2000]: D_loss: 0.326 | G_loss: 2.546
# Epoch: [1100/2000]: D_loss: 0.318 | G_loss: 2.571
# Epoch: [1101/2000]: D_loss: 0.321 | G_loss: 2.590
# Epoch: [1102/2000]: D_loss: 0.348 | G_loss: 2.575
# Epoch: [1103/2000]: D_loss: 0.341 | G_loss: 2.574
# Epoch: [1104/2000]: D_loss: 0.356 | G_loss: 2.611
# Epoch: [1105/2000]: D_loss: 0.317 | G_loss: 2.603
# Epoch: [1106/2000]: D_loss: 0.322 | G_loss: 2.601
# Epoch: [1107/2000]: D_loss: 0.348 | G_loss: 2.575
# Epoch: [1108/2000]: D_loss: 0.337 | G_loss: 2.545
# Epoch: [1109/2000]: D_loss: 0.321 | G_loss: 2.570
# Epoch: [1110/2000]: D_loss: 0.338 | G_loss: 2.583
# Epoch: [1111/2000]: D_loss: 0.373 | G_loss: 2.605
# Epoch: [1112/2000]: D_loss: 0.345 | G_loss: 2.593
# Epoch: [1113/2000]: D_loss: 0.312 | G_loss: 2.561
# Epoch: [1114/2000]: D_loss: 0.319 | G_loss: 2.541
# Epoch: [1115/2000]: D_loss: 0.317 | G_loss: 2.602
# Epoch: [1116/2000]: D_loss: 0.326 | G_loss: 2.628
# Epoch: [1117/2000]: D_loss: 0.317 | G_loss: 2.639
# Epoch: [1118/2000]: D_loss: 0.344 | G_loss: 2.561
# Epoch: [1119/2000]: D_loss: 0.352 | G_loss: 2.645
# Epoch: [1120/2000]: D_loss: 0.314 | G_loss: 2.605
# Epoch: [1121/2000]: D_loss: 0.356 | G_loss: 2.529
# Epoch: [1122/2000]: D_loss: 0.348 | G_loss: 2.599
# Epoch: [1123/2000]: D_loss: 0.331 | G_loss: 2.515
# Epoch: [1124/2000]: D_loss: 0.338 | G_loss: 2.624
# Epoch: [1125/2000]: D_loss: 0.305 | G_loss: 2.625
# Epoch: [1126/2000]: D_loss: 0.334 | G_loss: 2.567
# Epoch: [1127/2000]: D_loss: 0.328 | G_loss: 2.700
# Epoch: [1128/2000]: D_loss: 0.347 | G_loss: 2.573
# Epoch: [1129/2000]: D_loss: 0.328 | G_loss: 2.565
# Epoch: [1130/2000]: D_loss: 0.324 | G_loss: 2.618
# Epoch: [1131/2000]: D_loss: 0.328 | G_loss: 2.594
# Epoch: [1132/2000]: D_loss: 0.329 | G_loss: 2.606
# Epoch: [1133/2000]: D_loss: 0.333 | G_loss: 2.553
# Epoch: [1134/2000]: D_loss: 0.337 | G_loss: 2.610
# Epoch: [1135/2000]: D_loss: 0.324 | G_loss: 2.623
# Epoch: [1136/2000]: D_loss: 0.315 | G_loss: 2.590
# Epoch: [1137/2000]: D_loss: 0.367 | G_loss: 2.618
# Epoch: [1138/2000]: D_loss: 0.339 | G_loss: 2.651
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-96494e1471d1> in <cell line: 19>()
#      24         D_optimizer.zero_grad()
#      25         # Real Data
# ---> 26         real_images = real_images.to(dev)
#      27         # Real labels
#      28         labels = labels.to(dev)
#
# KeyboardInterrupt:

# %%
x = [i * 250 for i in range(0,len(all_fid))]
plt.ylabel("FID")
plt.xlabel("#Epochs")
plt.plot(x,all_fid, 'o-r') # plot x and y using blue circle markers
plt.show()

# %%
torch.save(generator, 'generatorENTIRE.pth')
torch.save(discriminator, 'discriminatorENTIRE.pth')

# %%
generator = torch.load('generatorENTIRE.pth')

# %%
generator = torch.load('generatorENTIRE.pth')
discriminator = torch.load('discriminatorENTIRE.pth')
generator.eval()
print(summary(generator))
print(summary(discriminator))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Generator                                --
# ├─Sequential: 1-1                        --
# │    └─Embedding: 2-1                    500
# │    └─Linear: 2-2                       1,616
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-3                       827,392
# │    └─LeakyReLU: 2-4                    --
# ├─Sequential: 1-3                        --
# │    └─ConvTranspose2d: 2-5              4,202,496
# │    └─BatchNorm2d: 2-6                  1,024
# │    └─ReLU: 2-7                         --
# │    └─ConvTranspose2d: 2-8              2,097,152
# │    └─BatchNorm2d: 2-9                  512
# │    └─ReLU: 2-10                        --
# │    └─ConvTranspose2d: 2-11             524,288
# │    └─BatchNorm2d: 2-12                 256
# │    └─ReLU: 2-13                        --
# │    └─ConvTranspose2d: 2-14             6,144
# │    └─Tanh: 2-15                        --
# =================================================================
# Total params: 7,661,380
# Trainable params: 7,661,380
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Discriminator                            --
# ├─Sequential: 1-1                        --
# │    └─Embedding: 2-1                    500
# │    └─Linear: 2-2                       1,241,088
# ├─Sequential: 1-2                        --
# │    └─Conv2d: 2-3                       6,144
# │    └─LeakyReLU: 2-4                    --
# │    └─Conv2d: 2-5                       131,072
# │    └─BatchNorm2d: 2-6                  256
# │    └─LeakyReLU: 2-7                    --
# │    └─Conv2d: 2-8                       524,288
# │    └─BatchNorm2d: 2-9                  512
# │    └─LeakyReLU: 2-10                   --
# │    └─Flatten: 2-11                     --
# │    └─Dropout: 2-12                     --
# │    └─Linear: 2-13                      16,385
# │    └─Sigmoid: 2-14                     --
# =================================================================
# Total params: 1,920,245
# Trainable params: 1,920,245
# Non-trainable params: 0
# =================================================================

# %%
grid_img_real = vutils.make_grid(next(iter(dataloader))[0], nrow=8)
grid_img_GAN = vutils.make_grid(generated_image.cpu().detach(), nrow=8)
showarray(grid_img_real.permute(1, 2, 0), grid_img_GAN.permute(1, 2, 0), title1 = "Real", title2 = "GAN")

# %% [markdown]
# # Classification (original dataset)

# %% [markdown]
# ## Define train, val and test set

# %%
image_dir = "/content/fruit dataset"
image_size = 64
transform = T.Compose([
    T.Resize((image_size,image_size)),
    T.RandomHorizontalFlip(0.5),
    T.RandomVerticalFlip(0.5),
    T.ToTensor(),
    T.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])])
dataset = fruit(image_dir, transforms=transform)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True, drop_last = True, num_workers = 2)

train_size = int(len(dataset) * 0.70)
val_size = int(len(dataset)*0.15)
test_size = len(dataset) - (train_size+val_size)
train_set, val_set, test_set = random_split(dataset, [train_size , val_size, test_size])

print(f'Training set size: {train_size}\nValidation set size: {val_size}\nTest set size: {test_size}')

# Dataloader for train val and test
train_loader = DataLoader(train_set, batch_size=8, shuffle=True, drop_last = True, num_workers = 2) #collate_fn = collate_fn
val_loader = DataLoader(val_set, batch_size=8, shuffle=False,  drop_last = False, num_workers = 2) #collate_fn = collate_fn
test_loader = DataLoader(test_set, batch_size=8, shuffle=False,  drop_last = False, num_workers = 2)
# Out:
# Training set size: 1829
# Validation set size: 392
# Test set size: 393

# %% [markdown]
# ## Train

# %%
class SeqCNN(nn.Module):

    # Constructor
  def __init__(self):
    # Call parent contructor
    super().__init__()
    self.conv_layer = nn.Sequential(
       # Layer 1
        nn.Conv2d(in_channels=3, out_channels=3, kernel_size=9, padding=0, stride=1),
   #     nn.BatchNorm2d(64),
        nn.ReLU(),
        # Layer 2
        nn.Conv2d(in_channels=3, out_channels=3, kernel_size=9, padding=0, stride=1),
  #      nn.BatchNorm2d(64),
        nn.ReLU(),
  
        nn.MaxPool2d(kernel_size=2, stride=2)
       
    )

  # Forward
  def forward(self, x):
    x = self.conv_layer(x)
    return x
seq_net = SeqCNN()
img_x, _, _ = train_set[0]
img_x = img_x.unsqueeze(dim=0)
output = seq_net(img_x)
print(output.shape)
out_features = output.size(1) * output.size(2) * output.size(3)
print(out_features)
# Out:
# torch.Size([1, 3, 24, 24])
# 1728

# %%
class CNN(nn.Module):
  def __init__(self):
    # Call parent contructor
    super().__init__()
    self.conv_layer = nn.Sequential(
       # Layer 1
        nn.Conv2d(in_channels=3, out_channels=3, kernel_size=9, padding=0, stride=1),
   #     nn.BatchNorm2d(64),
        nn.ReLU(),
        # Layer 2
        nn.Conv2d(in_channels=3, out_channels=3, kernel_size=9, padding=0, stride=1),
  #      nn.BatchNorm2d(64),
        nn.ReLU(),
    
        nn.MaxPool2d(kernel_size=2, stride=2)
       
    )
    # Create fully-connected layers
    self.fc_layers = nn.Sequential(
        # a first FC layer
        nn.Linear(out_features, 10),  
        nn.ReLU(),
        # the final Classification Layer
        nn.Linear(10, 5)
    )

  # Forward
  def forward(self, x):
    x = self.conv_layer(x)     # x has size [B,3,24,24]; before passing to fc layer, we have to flatten x
    x = x.view(x.size(0), -1)  # now x has size [B, 1728]
    output = self.fc_layers(x) # [B, 1728] --> [B, 10] --> [B, 5]
    return output

model = CNN()
# Define an optimizier
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr = 0.001)
# Define a loss 
criterion = nn.CrossEntropyLoss()

# %%
def train(net, loaders, optimizer, criterion, epochs=5, dev=torch.device('cpu')):
    start_time = time.time() #(for showing time)
    try:
        net = net.to(dev)
    #    print(net)
        # Initialize history
        history_loss = {"train": [], "val": [], "test": []} #, "test": []
        history_accuracy = {"train": [], "val": [], "test": []}  #, "test": []
        # Process each epoch
        for epoch in range(epochs):
            # Initialize epoch variables
            sum_loss = {"train": 0, "val": 0,"test": 0}  #,"test": 0
            sum_accuracy = {"train": 0, "val": 0,"test": 0}  #,"test": 0
            # Process each split
            for split in ["train", "val", "test"]:  #, "test"
                if split == "train":
                  net.train()
                else:
                  net.eval()
                # Process each batch
                for (input, labels, _) in loaders[split]:
                    # Move to CUDA
                    input = input.to(dev)
                    labels = labels.to(dev)
                    # Reset gradients
                    optimizer.zero_grad()
                    # Compute output
                    outputs = net(input)
                    loss = criterion(outputs, labels)
                    # Update loss
                    sum_loss[split] += loss.item()
                    # Check parameter update
                    if split == "train":
                        # Compute gradients
                        loss.backward()
                        # Optimize
                        optimizer.step()
                    # Compute accuracy
                    preds = torch.argmax(outputs, 1)
                    batch_accuracy = (preds == labels).sum().item()/input.size(0)
                    # Update accuracy
                    sum_accuracy[split] += batch_accuracy
            # Compute epoch loss/accuracy
            epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}  #, "test"
            epoch_accuracy = {split: sum_accuracy[split]/len(loaders[split]) for split in ["train", "val", "test"]}  #, "test"
            # Update history
            for split in ["train", "val", "test"]:   #, "test"
                history_loss[split].append(epoch_loss[split])
                history_accuracy[split].append(epoch_accuracy[split])
            # Print info
            print(f"Epoch {epoch+1}:",
                  f"TrACC={epoch_accuracy['train']:.4f},",
                  f"TrLoss={epoch_loss['train']:.4f} ||",
                  f"ValACC={epoch_accuracy['val']:.4f},",
                  f"ValLoss={epoch_loss['val']:.4f} ||",
                  f"TestACC={epoch_accuracy['test']:.4f},",
                  f"TestLoss={epoch_loss['test']:.4f} ||",
                  f"Overall time:{str(datetime.timedelta(seconds=int(time.time()- start_time)))}")       
    except KeyboardInterrupt:
        print("Interrupted")
    finally:
        # Plot accuracy
        plt.title("Accuracy")
        for split in ["train", "val", "test"]:  #, "test"
            plt.plot(history_accuracy[split], label=split)
        plt.legend()
        plt.show()
        # Plot loss
        plt.title("Loss")
        for split in ["train", "val", "test"]:  #, "test"
            plt.plot(history_loss[split], label=split)
        plt.legend()
        plt.show()

# Define dictionary of loaders
loaders = {"train": train_loader,  #train_data_loader.
           "val": val_loader,   #test_data_loader
           "test": test_loader}

# %%
train(model, loaders, optimizer, criterion, epochs=5, dev=dev)
# Out:
# Epoch 1: TrACC=0.8317, TrLoss=0.3998 || ValACC=0.8903, ValLoss=0.5037 || TestACC=0.8900, TestLoss=0.5900 || Overall time:0:00:03
# Epoch 2: TrACC=0.9814, TrLoss=0.0779 || ValACC=0.9949, ValLoss=0.0233 || TestACC=0.9975, TestLoss=0.0119 || Overall time:0:00:07
# Epoch 3: TrACC=0.9978, TrLoss=0.0208 || ValACC=0.9974, ValLoss=0.0063 || TestACC=1.0000, TestLoss=0.0021 || Overall time:0:00:12
# Epoch 4: TrACC=1.0000, TrLoss=0.0017 || ValACC=1.0000, ValLoss=0.0010 || TestACC=1.0000, TestLoss=0.0012 || Overall time:0:00:16
# Epoch 5: TrACC=1.0000, TrLoss=0.0008 || ValACC=1.0000, ValLoss=0.0011 || TestACC=1.0000, TestLoss=0.0005 || Overall time:0:00:19

# %% [markdown]
# # Classification (with Gan)

# %% [markdown]
# ## Generate 100 images for each class

# %%
if os.path.exists("Fake_images_for_classification"):
  shutil.rmtree('Fake_images_for_classification')

os.makedirs('Fake_images_for_classification/train/apple braeburn')
os.makedirs('Fake_images_for_classification/train/lemon')
os.makedirs('Fake_images_for_classification/train/pear')
os.makedirs('Fake_images_for_classification/train/pepper Green')
os.makedirs('Fake_images_for_classification/train/pineapple')

# %%
label0 = torch.tensor([0]).to(dev)
label0 = label0.unsqueeze(1).long()
label1 = torch.tensor([1]).to(dev)
label1 = label1.unsqueeze(1).long()
label2 = torch.tensor([2]).to(dev)
label2 = label2.unsqueeze(1).long()
label3 = torch.tensor([3]).to(dev)
label3 = label3.unsqueeze(1).long()
label4 = torch.tensor([4]).to(dev)
label4 = label4.unsqueeze(1).long()

generator.eval()

label_list = [label0, label1, label2, label3, label4]
class_list = ['apple braeburn', 'lemon', 'pear', 'pepper Green', 'pineapple']

for class_idx, class_label in enumerate(class_list):
    for i in range(100):
        noise_vector = torch.randn(1, z_dim, device=dev)
        generated_single_image = generator((noise_vector, label_list[class_idx]))
        save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/{class_label}/{class_label}_{i}.png", nrow=5, normalize=True)
'''
for i in range(100):
  noise_vector = torch.randn(1, z_dim, device=dev)  
  #noise_vector = noise_vector.to(dev)
  generated_single_image = generator((noise_vector, label0))
  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/apple braeburn/apple braeburn_{i}.png", nrow=5, normalize=True)

for i in range(100):
  noise_vector = torch.randn(1, z_dim, device=dev)  
  #noise_vector = noise_vector.to(dev)
  generated_single_image = generator((noise_vector, label1))
  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/lemon/lemon_{i}.png", nrow=5, normalize=True)

for i in range(100):
  noise_vector = torch.randn(1, z_dim, device=dev)  
  #noise_vector = noise_vector.to(dev)
  generated_single_image = generator((noise_vector, label2))
  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pear/pear_{i}.png", nrow=5, normalize=True)

for i in range(100):
  noise_vector = torch.randn(1, z_dim, device=dev)  
  #noise_vector = noise_vector.to(dev)
  generated_single_image = generator((noise_vector, label3))
  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pepper Green/pepper Green_{i}.png", nrow=5, normalize=True)

for i in range(100):
  noise_vector = torch.randn(1, z_dim, device=dev)  
  #noise_vector = noise_vector.to(dev)
  generated_single_image = generator((noise_vector, label4))
  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pineapple/pineapple_{i}.png", nrow=5, normalize=True)
'''
# Out:
# '\nfor i in range(100):\n  noise_vector = torch.randn(1, z_dim, device=dev)  \n  #noise_vector = noise_vector.to(dev)\n  generated_single_image = generator((noise_vector, label0))\n  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/apple braeburn/apple braeburn_{i}.png", nrow=5, normalize=True)\n\nfor i in range(100):\n  noise_vector = torch.randn(1, z_dim, device=dev)  \n  #noise_vector = noise_vector.to(dev)\n  generated_single_image = generator((noise_vector, label1))\n  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/lemon/lemon_{i}.png", nrow=5, normalize=True)\n\nfor i in range(100):\n  noise_vector = torch.randn(1, z_dim, device=dev)  \n  #noise_vector = noise_vector.to(dev)\n  generated_single_image = generator((noise_vector, label2))\n  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pear/pear_{i}.png", nrow=5, normalize=True)\n\nfor i in range(100):\n  noise_vector = torch.randn(1, z_dim, device=dev)  \n  #noise_vector = noise_vector.to(dev)\n  generated_single_image = generator((noise_vector, label3))\n  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pepper Green/pepper Green_{i}.png", nrow=5, normalize=True)\n\nfor i in range(100):\n  noise_vector = torch.randn(1, z_dim, device=dev)  \n  #noise_vector = noise_vector.to(dev)\n  generated_single_image = generator((noise_vector, label4))\n  save_image(generated_single_image.data[0].detach(), f"Fake_images_for_classification/train/pineapple/pineapple_{i}.png", nrow=5, normalize=True)\n'

# %% [markdown]
# ## Define new dataset (original + GAN images)

# %%
image_dir = "/content/Fake_images_for_classification/train"
dataset_GAN = fruit(image_dir, transforms=transform)
concat_training_set = ConcatDataset([train_set, dataset_GAN])
print(f'Training set (of original training images + gan images): {len(concat_training_set)}')
concat_dataloader = DataLoader(concat_training_set, batch_size=64, shuffle=True, drop_last = True, num_workers = 2)
# Out:
# Training set (of original training images + gan images): 2329

# %% [markdown]
# ## Train

# %%
model = CNN()
# Define an optimizier
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr = 0.001)
# Define a loss 
criterion = nn.CrossEntropyLoss()

# %%
def train(net, loaders, optimizer, criterion, epochs=10, dev=torch.device('cpu')):
    start_time = time.time() #(for showing time)
    try:
        net = net.to(dev)
    #    print(net)
        # Initialize history
        history_loss = {"train": [], "val": [], "test": []} #, "test": []
        history_accuracy = {"train": [], "val": [], "test": []}  #, "test": []
        # Process each epoch
        for epoch in range(epochs):
            # Initialize epoch variables
            sum_loss = {"train": 0, "val": 0,"test": 0}  #,"test": 0
            sum_accuracy = {"train": 0, "val": 0,"test": 0}  #,"test": 0
            # Process each split
            for split in ["train", "val", "test"]:  #, "test"
                if split == "train":
                  net.train()
                else:
                  net.eval()
                # Process each batch
                for (input, labels, _) in loaders[split]:
                    # Move to CUDA
                    input = input.to(dev)
                    labels = labels.to(dev)
                    # Reset gradients
                    optimizer.zero_grad()
                    # Compute output
                    outputs = net(input)
                    loss = criterion(outputs, labels)
                    # Update loss
                    sum_loss[split] += loss.item()
                    # Check parameter update
                    if split == "train":
                        # Compute gradients
                        loss.backward()
                        # Optimize
                        optimizer.step()
                    # Compute accuracy
                    preds = torch.argmax(outputs, 1)
                    batch_accuracy = (preds == labels).sum().item()/input.size(0)
                    # Update accuracy
                    sum_accuracy[split] += batch_accuracy
            # Compute epoch loss/accuracy
            epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}  #, "test"
            epoch_accuracy = {split: sum_accuracy[split]/len(loaders[split]) for split in ["train", "val", "test"]}  #, "test"
            # Update history
            for split in ["train", "val", "test"]:   #, "test"
                history_loss[split].append(epoch_loss[split])
                history_accuracy[split].append(epoch_accuracy[split])
            # Print info
            print(f"Epoch {epoch+1}:",
                  f"TrACC={epoch_accuracy['train']:.4f},",
                  f"TrLoss={epoch_loss['train']:.4f} ||",
                  f"ValACC={epoch_accuracy['val']:.4f},",
                  f"ValLoss={epoch_loss['val']:.4f} ||",
                  f"TestACC={epoch_accuracy['test']:.4f},",
                  f"TestLoss={epoch_loss['test']:.4f} ||",
                  f"Overall time:{str(datetime.timedelta(seconds=int(time.time()- start_time)))}")       
    except KeyboardInterrupt:
        print("Interrupted")
    finally:
        # Plot accuracy
        plt.title("Accuracy")
        for split in ["train", "val", "test"]:  #, "test"
            plt.plot(history_accuracy[split], label=split)
        plt.legend()
        plt.show()
        # Plot loss
        plt.title("Loss")
        for split in ["train", "val", "test"]:  #, "test"
            plt.plot(history_loss[split], label=split)
        plt.legend()
        plt.show()

# Define dictionary of loaders
loaders = {"train": concat_dataloader, #concat_dataloader,  
           "val": val_loader,   #val_loader_GAN
           "test": test_loader}  #test_loader_GAN

# %%
train(model, loaders, optimizer, criterion, epochs=5, dev=dev)
# Out:
# Epoch 1: TrACC=0.5929, TrLoss=0.9105 || ValACC=0.9388, ValLoss=0.2710 || TestACC=0.9375, TestLoss=0.2949 || Overall time:0:00:04
# Epoch 2: TrACC=0.9549, TrLoss=0.1502 || ValACC=0.9592, ValLoss=0.1055 || TestACC=0.9725, TestLoss=0.1021 || Overall time:0:00:10
# Epoch 3: TrACC=0.9813, TrLoss=0.0623 || ValACC=0.9949, ValLoss=0.0227 || TestACC=1.0000, TestLoss=0.0258 || Overall time:0:00:13
# Epoch 4: TrACC=0.9926, TrLoss=0.0284 || ValACC=1.0000, ValLoss=0.0146 || TestACC=0.9900, TestLoss=0.0328 || Overall time:0:00:16
# Epoch 5: TrACC=0.9918, TrLoss=0.0325 || ValACC=0.9974, ValLoss=0.0113 || TestACC=0.9975, TestLoss=0.0172 || Overall time:0:00:20

# %% [markdown]
# We can conclude that our GAN images are able to let the model classify the images with the same (very high) accuracy as the original dataset.

# %%
torch.save(model, 'model.pth')

# %% [markdown]
# # CAPTUM

# %%
model = model.eval()
test_img = Image.open("/content/Fake_images_for_classification/train/lemon/lemon_11.png")
test_img_data = np.asarray(test_img)
plt.imshow(test_img_data)
plt.show()

# %%
transform = T.Compose([
    T.Resize((image_size,image_size)),
    T.ToTensor()
])
    
transform_norm = T.Compose([
    T.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])])

# perform same data transforms on our own data as the model
transformed_img = transform(test_img)
input_img = transform_norm(transformed_img)
input_img = input_img.unsqueeze(dim=0).to(dev) # the model requires a dummy batch dimension

# %%
from captum.attr import GuidedGradCam, NoiseTunnel
from captum.attr import visualization as viz, LayerGradCam, LayerAttribution

# %%
output = model(input_img)
output = F.softmax(output, dim=1)
prediction_score, pred_label_idx = torch.topk(output, 1)
prediction_score, pred_label_idx = torch.topk(output, 1)
pred_label_idx.squeeze_()
print(pred_label_idx)
# Out:
# tensor(1, device='cuda:0')

# %% [markdown]
# ### GradCam with noise tunnel

# %%
gg = GuidedGradCam(model, model.conv_layer[2]) #Guided GradCam on last block 
noise_tunnel = NoiseTunnel(gg) #noise tunnel on Guided GradCam
attributions_ig_nt = noise_tunnel.attribute(input_img, nt_samples=10, nt_type='smoothgrad_sq', target=pred_label_idx, stdevs=0.4)
#visualize
_ = viz.visualize_image_attr_multiple(np.transpose(attributions_ig_nt.squeeze().cpu().detach().numpy(), (1,2,0)), #noise tunneled Guided GradCam
                                      np.transpose(transformed_img.squeeze().cpu().detach().numpy(), (1,2,0)), #unormalized img
                                      ["original_image", "heat_map"],
                                      ["all", "positive"],
                                      cmap=cm.seismic,
                                      show_colorbar=True)

# %% [markdown]
# ### Integrated gradient with noise tunnel

# %%
from captum.attr import NoiseTunnel, IntegratedGradients
# Initialize the attribution algorithm with the model
integrated_gradients = IntegratedGradients(model)

noise_tunnel = NoiseTunnel(integrated_gradients)

attributions_ig_nt = noise_tunnel.attribute(input_img, nt_samples=10, nt_type='smoothgrad_sq', target=pred_label_idx, internal_batch_size=10)
_ = viz.visualize_image_attr_multiple(np.transpose(attributions_ig_nt.squeeze().cpu().detach().numpy(), (1,2,0)),
                                      np.transpose(transformed_img.squeeze().cpu().detach().numpy(), (1,2,0)),
                                      ["original_image", "heat_map"],
                                      ["all", "positive"],
                                      cmap=cm.seismic,
                                      show_colorbar=True)
